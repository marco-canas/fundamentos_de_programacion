# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad3/8_chapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad3/8_chapter.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display
from PIL import Image

def generar_qr(url, version=1, box_size=4, border=4, fill_color="black", back_color="white"):
    """
    Genera y muestra un código QR para una URL dada en un Jupyter Notebook.
    
    Parámetros:
    - url: La URL para la cual generar el código QR
    - version: Tamaño del QR (1-40, donde 1 es el más pequeño)
    - box_size: Número de píxeles por cada "caja" del QR
    - border: Grosor del borde blanco alrededor del QR (en cajas)
    - fill_color: Color del código QR
    - back_color: Color de fondo del código QR
    
    Retorna:
    - Muestra el código QR directamente en el notebook
    - Retorna el objeto QR generado
    """
    # Configurar el generador de QR
    qr = qrcode.QRCode(
        version=version,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=box_size,
        border=border,
    )
    
    # Añadir la URL al QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color=fill_color, back_color=back_color)
     
    return img

# Ejemplo de uso:
# generar_qr("https://www.ejemplo.com")

# %%
url = "https://colab.research.google.com/github/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad3/8_chapter.ipynb"
generar_qr(url)

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso de Fundamentos de Programación:](https://github.com/marco-canas/fundamentos_de_programacion/blob/main/programa/Programa_Fundamentos_Programacion.md)

# %% [markdown]
# ## Código del curso: 314029

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/algebra_y_trigonometria/blob/main/7_images/5_clase_3_2025-08-12_hora_11_04.jpg?raw=true' width = 300>

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/fundamentos_programacion.xlsx'
df = pd.read_excel(path)
df.index = np.arange(1, len(df) + 1)  # Cambiar el índice para que empiece en 1
df.head(8)
# Out:
#        Cédula                             Nombre  \
# 1  1038648096            ACEVEDO BELEÑO SANTIAGO
# 2  1038113597            CORREA RESTREPO NICOLAS
# 3  1038648760   MARIN VILLARREAL PABLO ALEJANDRO
# 4  1038647828    NIEBLES BARRERA ALEXANDER ISAAC
# 5  1038136953        PATINO GIL CHRISTIAN FELIPE
# 6  1038092717             RIVERA GUZMAN CRISTIAN
# 7  1066600819  TIRADO CHAVARRIA WILFRAN DE JESUS
#
#                            Email
# 1    sacevedo.beleno@udea.edu.co
# 2  nicolas.crestrepo@udea.edu.co
# 3       pablo.marin1@udea.edu.co
# 4  alexander.niebles@udea.edu.co
# 5  christian.patino1@udea.edu.co
# 6   cristian.rivera2@udea.edu.co
# 7     wilfran.tirado@udea.edu.co

# %% [markdown]
# ### Principios de mi labor docente

# %% [markdown]
# ### Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# ### Metodología de Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 100>

# %% [markdown]
# ### Desarrollo del pensamiento computacional con Lenguajes Python y con archivos Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 100>

# %% [markdown]
# ### Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 100>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# ### Y el enfoque de TRRS de Duval

# %% [markdown]
# # Chapter 8. Introducción al análisis de datos

# %% [markdown]
# ## Una perspectiva para estudiantes de Matemáticas Puras

# %% [markdown]
# En el capítulo anterior trabajamos la **entrada y salida de archivos en Python**. Puede parecer un tema meramente técnico, pero en realidad es el primer paso hacia algo más profundo: **la formalización computacional de la información**.

# %% [markdown]
# En matemáticas puras estamos acostumbrados a:
#
# * Definir con precisión.
# * Establecer hipótesis.
# * Construir demostraciones.
# * Analizar estructuras.
#
# El análisis de datos no es ajeno a esta lógica. De hecho, puede entenderse como una **forma aplicada del pensamiento matemático**, donde:
#
# * Los datos son objetos.
# * Los modelos son estructuras.
# * Las conclusiones son resultados inferenciales.
#
# Vivimos en la **era de los datos**. La cantidad de información generada crece exponencialmente. Pero los datos por sí solos no tienen valor matemático hasta que:
#
# * Se organizan.
# * Se transforman.
# * Se interpretan bajo un marco conceptual.
#
# Ahí es donde interviene el análisis de datos.
#
# ---
#
# # ¿Qué es el análisis de datos desde una mirada matemática?
#
# De manera general:
#
# > El análisis de datos es el proceso de extraer información estructurada y significativa a partir de datos sin procesar, utilizando métodos matemáticos, estadísticos y computacionales.
#
# Observa que esta definición involucra tres dimensiones:
#
# 1. **Estructura** → organización formal.
# 2. **Transformación** → aplicación de operadores.
# 3. **Inferencia** → extracción de conclusiones.
#
# Desde una perspectiva formal, el análisis de datos puede verse como:
#
# [
# \text{Datos crudos} \xrightarrow{\text{Transformaciones}} \text{Estructuras interpretables}
# ]
#
# Es un proceso secuencial, similar a una demostración matemática: cada paso depende del anterior.
#
# ---
#
# # Análisis de datos vs. Analítica de datos
#
# Es importante distinguir conceptualmente ambos términos.
#
# ## 🔹 Análisis de datos
#
# * Estudia datos pasados.
# * Describe y explica fenómenos.
# * Responde:
#   **¿Qué ocurrió?**
#   **¿Por qué ocurrió?**
#
# ## 🔹 Analítica de datos
#
# * Utiliza modelos avanzados.
# * Predice comportamientos futuros.
# * Responde:
#   **¿Qué podría ocurrir?**
#
# Desde una perspectiva matemática:
#
# * El análisis se apoya en estadística descriptiva e inferencial.
# * La analítica involucra modelación, optimización y aprendizaje automático.
#
# ---
#
# # ¿Por qué debe interesarle esto a un matemático puro?
#
# Podrías preguntarte:
# *"¿No es esto más propio de la estadística aplicada o la ingeniería?"*
#
# Sin embargo, el análisis de datos involucra conceptos profundamente matemáticos:
#
# * Espacios vectoriales (datos como vectores).
# * Álgebra lineal (transformaciones, reducción de dimensión).
# * Probabilidad y estadística.
# * Optimización.
# * Teoría de la información.
# * Análisis numérico.
#
# El matemático puro aporta:
#
# * Rigor conceptual.
# * Capacidad de abstracción.
# * Comprensión estructural de los modelos.
# * Análisis crítico de supuestos.
#
# En un entorno como el **Campus Caucasia**, donde los problemas sociales, económicos y ambientales son reales y complejos, el matemático puede convertirse en un puente entre teoría y realidad mediante el análisis de datos.
#
# ---
#
# # Tipos de análisis de datos (Una lectura estructural)
#
# Podemos entenderlos como niveles de profundidad en la interpretación.
#
# ## 1️⃣ Análisis descriptivo
#
# Responde: **¿Qué sucedió?**
#
# Ejemplo:
#
# * Resumen estadístico.
# * Media, varianza, distribución.
# * Reportes de ventas.
#
# Matemáticamente:
# [
# \text{Resumen} = f(\text{Datos})
# ]
#
# ---
#
# ## 2️⃣ Análisis diagnóstico
#
# Responde: **¿Por qué sucedió?**
#
# Aquí buscamos relaciones causales o correlacionales.
#
# Matemáticamente:
#
# * Modelos de regresión.
# * Análisis de dependencia.
# * Estudio de correlaciones.
#
# ---
#
# ## 3️⃣ Análisis predictivo
#
# Responde: **¿Qué puede suceder?**
#
# Se construyen modelos:
#
# [
# Y = f(X) + \varepsilon
# ]
#
# Donde:
#
# * ( f ) es un modelo.
# * ( \varepsilon ) es el error.
#
# Aquí entran:
#
# * Series de tiempo.
# * Modelos probabilísticos.
# * Machine Learning.
#
# ---
#
# ## 4️⃣ Análisis prescriptivo
#
# Responde: **¿Qué decisión debemos tomar?**
#
# Implica optimización:
#
# [
# \min_{x \in S} f(x)
# ]
#
# Sujeto a restricciones.
#
# Es el punto donde la matemática se convierte en acción.
#
# ---
#
# # Flujo del proceso de análisis de datos
#
# (Paralelo con el método matemático)
#
# El análisis de datos no es improvisado. Sigue un proceso estructurado:
#
# ## 1️⃣ Definición del problema
#
# Equivalente a formular un teorema o problema.
#
# ## 2️⃣ Recopilación de datos
#
# Recolección de evidencia.
#
# ## 3️⃣ Limpieza de datos
#
# Depuración de errores (análoga a verificar hipótesis).
#
# ## 4️⃣ Preparación
#
# Transformaciones algebraicas.
#
# ## 5️⃣ Análisis
#
# Aplicación de herramientas matemáticas.
#
# ## 6️⃣ Interpretación
#
# Discusión del resultado.
#
# ## 7️⃣ Comunicación
#
# Redacción de conclusiones.
#
# Observa que esto es muy similar a:
#
# [
# \text{Problema} \rightarrow \text{Formalización} \rightarrow \text{Desarrollo} \rightarrow \text{Conclusión}
# ]
#
# ---
#
# # Tipos de datos (Desde la estructura)
#
# ## 🔹 Datos estructurados
#
# * Tablas.
# * Matrices.
# * Bases de datos relacionales.
#
# Son los más cómodos para el análisis matemático.
#
# ---
#
# ## 🔹 Datos semiestructurados
#
# * JSON
# * CSV
# * XML
#
# Requieren interpretación estructural.
#
# ---
#
# ## 🔹 Datos no estructurados
#
# * Texto libre
# * Imágenes
# * Audio
#
# Aquí entran:
#
# * Procesamiento de lenguaje natural.
# * Análisis espectral.
# * Álgebra lineal aplicada.
#
# ---
#
# # Reflexión final para ustedes
#
# Como matemáticos en formación:
#
# * No deben limitarse a aplicar fórmulas.
# * Deben comprender la estructura del problema.
# * Deben cuestionar supuestos.
# * Deben analizar la validez de los modelos.
#
# El análisis de datos no reemplaza la matemática pura;
# la amplía hacia escenarios reales.
#
# Y en un contexto como el de Caucasia —con retos en salud pública, agricultura, clima y economía— la matemática puede convertirse en una herramienta de transformación social.
#
# ---
#
# # Preguntas para discusión en clase
#
# 1. ¿En qué sentido el análisis de datos puede formalizarse como un operador sobre espacios vectoriales?
# 2. ¿Todo modelo predictivo es una función bien definida?
# 3. ¿Qué papel juega el error ( \varepsilon ) desde una perspectiva epistemológica?
# 4. ¿Puede existir análisis de datos sin hipótesis implícitas?
# 5. ¿Dónde termina la matemática pura y comienza la aplicada?
#
# ---
#
# Si quieres, puedo ahora:
#
# * Diseñarte una **clase experimental en Jupyter** con ejemplos formales.
# * Conectar este capítulo con Álgebra Lineal y Espacios Vectoriales.
# * O estructurarlo como material para aula invertida en tu repositorio de GitHub.

# %% [markdown]
# <img src = 'proceso_de_analisis_de_datos.png'>

# %% [markdown]
# Perfecto, Marco. Aquí tienes la **versión pedagógica y matemáticamente orientada**, pensada para tus estudiantes de **Matemáticas Puras en la Universidad de Antioquia – Campus Caucasia**, manteniendo el rigor estructural y conectándolo con modelación, álgebra lineal, estadística y pensamiento formal.
#
# ---
#
# # El Proceso de Análisis de Datos
#
# ## Una lectura estructural para matemáticos en formación
#
# En matemáticas estamos acostumbrados a procesos bien definidos:
#
# [
# \text{Hipótesis} \rightarrow \text{Desarrollo lógico} \rightarrow \text{Conclusión}
# ]
#
# El análisis de datos sigue una lógica análoga:
#
# [
# \text{Problema} \rightarrow \text{Datos} \rightarrow \text{Transformación} \rightarrow \text{Modelo} \rightarrow \text{Interpretación}
# ]
#
# No es un procedimiento improvisado; es un **proceso estructurado**, comparable al método matemático.
#
# ---
#
# # 1️⃣ Requisitos: Recopilación y Planificación
#
# *(Formulación del problema)*
#
# Esta fase equivale a **definir el problema matemático**.
#
# Aquí no se calculan todavía resultados; se formaliza el contexto.
#
# Preguntas fundamentales:
#
# * ¿Qué queremos estudiar?
# * ¿Cuál es el dominio del problema?
# * ¿Qué tipo de análisis necesitamos?
# * ¿Qué datos representan el fenómeno?
# * ¿Qué limitaciones existen?
#
# Desde una perspectiva matemática:
#
# * Estamos definiendo el **espacio de trabajo**.
# * Identificamos variables.
# * Determinamos restricciones.
# * Establecemos objetivos (función objetivo implícita).
#
# Es la etapa donde pasamos del lenguaje cotidiano a una **formulación estructurada**.
#
# ---
#
# # 2️⃣ Recopilación de Datos
#
# *(Construcción del conjunto de trabajo)*
#
# Aquí construimos el conjunto:
#
# [
# D = {x_1, x_2, \dots, x_n}
# ]
#
# donde cada ( x_i ) puede verse como un vector en ( \mathbb{R}^k ).
#
# Fuentes posibles:
#
# * Web
# * Sistemas transaccionales
# * Sensores
# * Archivos estructurados
#
# Aspectos fundamentales:
#
# * Momento de medición (dependencia temporal).
# * Frecuencia de muestreo.
# * Calidad del dato.
#
# En términos matemáticos, estamos definiendo:
#
# * La muestra.
# * La dimensión del espacio.
# * La naturaleza del dominio.
#
# ---
#
# # 3️⃣ Limpieza de Datos
#
# *(Depuración estructural)*
#
# En esta etapa eliminamos inconsistencias.
#
# Si consideramos el conjunto original ( D ), la limpieza produce:
#
# [
# D_{\text{limpio}} \subseteq D
# ]
#
# Eliminamos:
#
# * Valores atípicos erróneos.
# * Registros corruptos.
# * Datos irrelevantes.
#
# Esto es análogo a:
#
# * Verificar hipótesis en una demostración.
# * Eliminar contradicciones.
# * Asegurar coherencia interna.
#
# Un modelo construido sobre datos inconsistentes es como una demostración con un supuesto falso.
#
# ---
#
# # 4️⃣ Preparación de Datos
#
# *(Transformaciones matemáticas)*
#
# Aquí aplicamos operadores sobre los datos.
#
# Si cada dato es un vector ( x \in \mathbb{R}^k ), podemos aplicar transformaciones:
#
# [
# T: \mathbb{R}^k \rightarrow \mathbb{R}^m
# ]
#
# Ejemplos:
#
# * Normalización.
# * Cambio de escala.
# * Creación de variables derivadas.
#
# El ejemplo del número telefónico es trivial, pero conceptualmente representa una **descomposición estructural**.
#
# En modelación real:
#
# * Transformamos variables no lineales.
# * Construimos variables indicadoras.
# * Realizamos reducción de dimensión.
#
# ---
#
# # 5️⃣ Análisis de Datos
#
# *(Aplicación de modelos)*
#
# Aquí aplicamos herramientas matemáticas:
#
# * Estadística descriptiva.
# * Regresión.
# * Series de tiempo.
# * Métodos de optimización.
# * Álgebra lineal aplicada.
#
# Un modelo típico puede escribirse como:
#
# [
# Y = f(X) + \varepsilon
# ]
#
# Donde:
#
# * ( f ) es una función o transformación.
# * ( \varepsilon ) es el término de error.
#
# En este punto, el matemático puro aporta:
#
# * Análisis crítico de supuestos.
# * Comprensión de estabilidad numérica.
# * Evaluación de convergencia.
# * Interpretación estructural del modelo.
#
# ---
#
# # 6️⃣ Interpretación de Resultados
#
# *(Discusión matemática)*
#
# Un resultado numérico no es suficiente.
#
# Debemos preguntarnos:
#
# * ¿Es consistente con las hipótesis?
# * ¿Es estable frente a perturbaciones?
# * ¿Es generalizable?
#
# Interpretar no es solo leer números; es comprender el significado estructural del resultado.
#
# ---
#
# # 7️⃣ Visualización
#
# *(Representación geométrica)*
#
# La visualización es una forma de geometrización del dato.
#
# Un gráfico puede verse como:
#
# [
# \phi: D \rightarrow \mathbb{R}^2
# ]
#
# Es una proyección que permite comprender patrones.
#
# Gráficos comunes:
#
# * Barras → Comparaciones discretas.
# * Histogramas → Distribuciones.
# * Líneas → Dependencia temporal.
#
# Visualizar es interpretar geométricamente la estructura algebraica.
#
# ---
#
# # Tipos de Datos (Una mirada estructural)
#
# ## 🔹 Datos estructurados
#
# * Representables como matrices.
# * Elementos de ( \mathbb{R}^{n \times m} ).
# * Ideales para álgebra lineal.
#
# Ejemplo: bases de datos relacionales.
#
# ---
#
# ## 🔹 Datos semiestructurados
#
# * Estructura parcial.
# * Requieren interpretación previa.
# * Transformables a matrices.
#
# Ejemplo: JSON, CSV, XML.
#
# ---
#
# ## 🔹 Datos no estructurados
#
# * Texto libre.
# * Imágenes.
# * Audio.
#
# Aquí intervienen:
#
# * Espacios vectoriales de alta dimensión.
# * Transformadas.
# * Métodos espectrales.
# * Procesamiento de señales.
#
# ---
#
# # Herramientas en Python (Desde la estructura matemática)
#
# ## 🐍 IPython
#
# Entorno interactivo que permite experimentar y verificar conjeturas computacionales.
#
# ---
#
# ## 🐼 Pandas
#
# Estructuras tipo matriz con indexación avanzada.
#
# Permite:
#
# * Filtrar subconjuntos.
# * Agregar datos.
# * Transformar estructuras.
#
# ---
#
# ## 🔢 NumPy
#
# Base del cálculo numérico:
#
# * Arrays como generalización de vectores.
# * Operaciones matriciales.
# * Cálculo eficiente.
#
# ---
#
# ## 📈 Matplotlib
#
# Geometrización del dato.
#
# Permite observar patrones que no son evidentes en forma algebraica.
#
# ---
#
# # Conclusión (Para ustedes como matemáticos)
#
# El proceso de análisis de datos no es simplemente técnico.
#
# Es:
#
# * Formalización.
# * Transformación.
# * Modelación.
# * Interpretación.
#
# Es matemática aplicada con estructura.
#
# En un contexto como Caucasia, donde existen desafíos reales en:
#
# * Agricultura.
# * Salud pública.
# * Economía local.
# * Medio ambiente.
#
# El matemático puede convertir teoría en herramienta transformadora.
#
# ---
#
# # Preguntas para discusión profunda
#
# 1. ¿Puede modelarse el flujo de análisis de datos como una composición de operadores?
# 2. ¿Qué significa realmente el término de error ( \varepsilon )?
# 3. ¿Todo proceso de limpieza implica una pérdida de información?
# 4. ¿Puede existir análisis sin modelo implícito?
# 5. ¿En qué punto el análisis de datos deja de ser matemática y se convierte en ingeniería?
#
# ---

# %% [markdown]
# Perfecto. Te propongo una **clase experimental para estudiantes de Matemáticas Puras** en la **Universidad de Antioquia – Campus Caucasia**, conectando el flujo completo de análisis de datos con conceptos formales de **Álgebra Lineal**.
#
# La idea es que no vean el análisis de datos como algo “aplicado sin teoría”, sino como **álgebra lineal en acción**.
#
# ---
#
# # 📘 Clase Experimental
#
# ## *El Proceso de Análisis de Datos como un Problema de Álgebra Lineal*
#
# **Duración sugerida:** 2–3 horas
# **Modalidad:** Taller teórico–experimental con demostraciones en Python
# **Nivel:** Segundo o tercer semestre (cuando ya han visto espacios vectoriales y matrices)
#
# ---
#
# # 🎯 Objetivos de la clase
#
# Al finalizar la sesión, el estudiante podrá:
#
# 1. Interpretar un conjunto de datos como un objeto matemático (matriz en ℝⁿˣᵖ).
# 2. Relacionar cada etapa del análisis de datos con conceptos de:
#
#    * Espacios vectoriales
#    * Transformaciones lineales
#    * Rango y dependencia lineal
#    * Descomposición espectral
#    * Proyecciones ortogonales
# 3. Comprender que técnicas como regresión o reducción de dimensión son problemas clásicos de álgebra lineal.
#
# ---
#
# # 🔷 Estructura de la Clase
#
# ---
#
# ## 1️⃣ Requisitos → Modelado matemático del problema
#
# ### En el flujo de datos:
#
# Se define el problema y los objetivos.
#
# ### En álgebra lineal:
#
# Se traduce el problema a un modelo:
#
# Si tenemos:
#
# * ( n ) observaciones
# * ( p ) variables
#
# Construimos una matriz:
#
# [
# X \in \mathbb{R}^{n \times p}
# ]
#
# Cada:
#
# * Fila = vector en ℝᵖ
# * Columna = vector en ℝⁿ
#
# 📌 Discusión con estudiantes:
#
# * ¿El conjunto de columnas genera un subespacio de ℝⁿ?
# * ¿Qué significa que haya variables redundantes?
# * ¿Cómo se interpreta la dependencia lineal en datos reales?
#
# ---
#
# ## 2️⃣ Recopilación de datos → Construcción de la matriz
#
# Aquí se construye explícitamente:
#
# [
# X =
# \begin{bmatrix}
# x_{11} & x_{12} & \dots & x_{1p} \
# x_{21} & x_{22} & \dots & x_{2p} \
# \vdots & \vdots & \ddots & \vdots \
# x_{n1} & x_{n2} & \dots & x_{np}
# \end{bmatrix}
# ]
#
# 💡 Pregunta clave:
#
# > ¿Qué pasa si una columna es combinación lineal de otras?
#
# → El rango disminuye.
# → El sistema pierde información independiente.
#
# Aquí conectamos con:
#
# * Rango
# * Base
# * Dimensión del subespacio generado
#
# ---
#
# ## 3️⃣ Limpieza de datos → Operaciones matriciales
#
# Eliminar datos corruptos puede verse como:
#
# * Eliminar filas → restricción del espacio
# * Eliminar columnas → reducción de dimensión
# * Reemplazar valores → transformación del operador
#
# Normalización:
#
# [
# \tilde{X} = X - \mu
# ]
#
# Esto es:
#
# * Traslación en ℝᵖ
# * Cambio de base implícito
#
# 📌 Concepto clave:
# Centrar datos equivale a proyectar respecto al vector constante.
#
# ---
#
# ## 4️⃣ Preparación de datos → Transformaciones lineales
#
# Agregar variables derivadas es aplicar una transformación:
#
# [
# T: \mathbb{R}^p \rightarrow \mathbb{R}^k
# ]
#
# Ejemplo:
#
# [
# Z = XA
# ]
#
# Donde:
#
# * ( A ) es una matriz de transformación.
# * Estamos cambiando representación.
#
# Discusión:
#
# * ¿Cuándo es invertible?
# * ¿Cuándo pierde información?
# * ¿Qué implica que det(A)=0?
#
# ---
#
# ## 5️⃣ Análisis de datos → Proyección y mínimos cuadrados
#
# Aquí conectamos con uno de los resultados más bellos del curso:
#
# ### 📌 Regresión lineal como proyección ortogonal
#
# Dado:
#
# [
# X\beta = y
# ]
#
# Si no tiene solución exacta:
#
# [
# \hat{\beta} = (X^TX)^{-1}X^Ty
# ]
#
# Esto es:
#
# [
# \text{Proyección de } y \text{ sobre } \text{Col}(X)
# ]
#
# 💡 Aquí se puede demostrar:
#
# * Ecuaciones normales
# * Existencia si ( X^TX ) es invertible
# * Relación con independencia lineal
#
# Este momento suele ser revelador para estudiantes de matemáticas puras.
#
# ---
#
# ## 6️⃣ Reducción de dimensión → Autovalores y autovectores
#
# Aquí entra:
#
# ### 📌 PCA (Análisis de Componentes Principales)
#
# Matriz de covarianza:
#
# [
# \Sigma = \frac{1}{n} X^T X
# ]
#
# Buscamos:
#
# [
# \Sigma v = \lambda v
# ]
#
# Interpretación:
#
# * Autovectores → direcciones principales
# * Autovalores → varianza explicada
# * Elegimos los mayores λ → reducción de dimensión
#
# Aquí conectamos con:
#
# * Teorema espectral
# * Bases ortogonales
# * Diagonalización
#
# ---
#
# ## 7️⃣ Visualización → Cambio de base geométrico
#
# Cuando proyectamos datos a 2 dimensiones:
#
# [
# Z = XV_k
# ]
#
# Estamos:
#
# * Cambiando de base
# * Representando el subespacio dominante
# * Eliminando direcciones de baja varianza
#
# Es literalmente álgebra lineal geométrica aplicada.
#
# ---
#
# # 🧪 Actividad Experimental en Clase
#
# ### Parte 1 – Construcción manual
#
# Darles un conjunto pequeño:
#
# [
# X =
# \begin{bmatrix}
# 1 & 2 \
# 2 & 4 \
# 3 & 6
# \end{bmatrix}
# ]
#
# Preguntar:
#
# * ¿Cuál es el rango?
# * ¿Qué implica?
# * ¿Qué ocurre con ( X^TX )?
#
# ---
#
# ### Parte 2 – Regresión como proyección
#
# Tomar:
#
# [
# y =
# \begin{bmatrix}
# 1 \
# 2 \
# 2
# \end{bmatrix}
# ]
#
# Hacer cálculo explícito de:
#
# [
# \hat{\beta}
# ]
#
# Mostrar que el residuo es ortogonal al espacio columna.
#
# ---
#
# ### Parte 3 – PCA geométrico
#
# Usar datos en ℝ² con correlación alta y:
#
# * Calcular matriz de covarianza
# * Encontrar autovectores
# * Dibujar dirección principal
#
# ---
#
# # 🧠 Cierre conceptual
#
# Reformular todo el flujo:
#
# | Flujo de Datos | Álgebra Lineal           |
# | -------------- | ------------------------ |
# | Datos          | Matriz                   |
# | Limpieza       | Restricción / proyección |
# | Preparación    | Transformación lineal    |
# | Regresión      | Proyección ortogonal     |
# | PCA            | Teorema espectral        |
# | Visualización  | Cambio de base           |
#
# ---
#
# # 🎓 Mensaje final para estudiantes
#
# El análisis de datos no es una moda tecnológica.
# Es la aplicación sistemática de:
#
# * Espacios vectoriales
# * Operadores lineales
# * Descomposición espectral
# * Geometría en ℝⁿ
#
# En otras palabras:
#
# > Data Science es Álgebra Lineal con contexto.
#
# ---

# %% [markdown]
# Perfecto. Te preparo un **laboratorio formal de Álgebra Lineal aplicada al análisis de datos**, completamente estructurado para trabajar en Python, conectando teoría y cálculo explícito.
#
# Este laboratorio está diseñado para que el estudiante vea:
#
# * Datos = matrices en ℝⁿˣᵖ
# * Regresión = proyección ortogonal
# * PCA = problema espectral
# * Visualización = cambio de base geométrico
#
# Usaremos:
#
# * NumPy (cálculo matricial)
# * Pandas (estructura de datos)
# * Matplotlib (visualización geométrica)
#
# ---
#
# # 🧪 Laboratorio: Álgebra Lineal en el Análisis de Datos
#
# ## 🎯 Objetivos
#
# 1. Interpretar un conjunto de datos como una matriz.
# 2. Calcular rango y dependencia lineal.
# 3. Resolver regresión lineal como proyección ortogonal.
# 4. Implementar PCA usando autovalores y autovectores.
# 5. Visualizar geométricamente los resultados.
#
# ---
#
# # 🔷 Parte 1 — Datos como matriz y rango
#
# ## 📌 1.1 Construcción del conjunto de datos
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Creamos un conjunto de datos simple con dependencia lineal
# X = np.array([
#     [1, 2],
#     [2, 4],
#     [3, 6]
# ])
#
# df = pd.DataFrame(X, columns=["x1", "x2"])
# print(df)
# ```
#
# ---
#
# ## 📌 1.2 Rango y dependencia lineal
#
# ```python
# rank = np.linalg.matrix_rank(X)
# print("Rango de X:", rank)
# ```
#
# ### 🔎 Análisis teórico
#
# * Las columnas son linealmente dependientes.
# * x2 = 2x1
# * El espacio columna tiene dimensión 1.
# * Col(X) es una recta en ℝ³.
#
# Discusión con estudiantes:
#
# * ¿Qué implica esto para la invertibilidad de ( X^T X )?
#
# ---
#
# # 🔷 Parte 2 — Regresión como Proyección Ortogonal
#
# Ahora construimos un problema:
#
# [
# X\beta = y
# ]
#
# ---
#
# ## 📌 2.1 Definimos el vector objetivo
#
# ```python
# y = np.array([1, 2, 2]).reshape(-1,1)
# ```
#
# ---
#
# ## 📌 2.2 Intentamos resolver el sistema directamente
#
# ```python
# try:
#     beta = np.linalg.inv(X.T @ X) @ X.T @ y
#     print("Beta:", beta)
# except:
#     print("X^T X no es invertible (dependencia lineal).")
# ```
#
# Aquí se observa el problema algebraico:
#
# * ( X^T X ) no es invertible.
# * El sistema no tiene solución única.
#
# ---
#
# ## 📌 2.3 Usamos pseudoinversa (proyección mínima)
#
# ```python
# beta_hat = np.linalg.pinv(X) @ y
# print("Solución mínima norma (pseudoinversa):")
# print(beta_hat)
# ```
#
# ---
#
# ## 📌 2.4 Verificación geométrica
#
# Calculamos la proyección:
#
# ```python
# y_hat = X @ beta_hat
# residuo = y - y_hat
#
# print("Producto X^T * residuo:")
# print(X.T @ residuo)
# ```
#
# 🔎 Resultado esperado:
#
# [
# X^T (y - \hat{y}) = 0
# ]
#
# Interpretación:
# El residuo es ortogonal al espacio columna.
#
# Esto demuestra formalmente que la regresión es una proyección ortogonal.
#
# ---
#
# # 🔷 Parte 3 — PCA como Problema Espectral
#
# Ahora generamos datos con correlación alta.
#
# ---
#
# ## 📌 3.1 Generación de datos correlacionados
#
# ```python
# np.random.seed(0)
#
# x1 = np.random.randn(100)
# x2 = 2*x1 + np.random.randn(100)*0.5
#
# X = np.column_stack((x1, x2))
# ```
#
# ---
#
# ## 📌 3.2 Centramos los datos
#
# ```python
# X_centered = X - np.mean(X, axis=0)
# ```
#
# Interpretación algebraica:
# Restar la media es una traslación en ℝ².
#
# ---
#
# ## 📌 3.3 Matriz de covarianza
#
# [
# \Sigma = \frac{1}{n} X^T X
# ]
#
# ```python
# cov_matrix = (X_centered.T @ X_centered) / len(X_centered)
# print("Matriz de covarianza:")
# print(cov_matrix)
# ```
#
# ---
#
# ## 📌 3.4 Autovalores y autovectores
#
# ```python
# eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
#
# print("Autovalores:")
# print(eigenvalues)
#
# print("Autovectores:")
# print(eigenvectors)
# ```
#
# Interpretación:
#
# * Autovectores → direcciones principales.
# * Autovalores → varianza en esa dirección.
#
# Aquí aplicamos directamente el Teorema Espectral.
#
# ---
#
# # 🔷 Parte 4 — Visualización Geométrica del Cambio de Base
#
# ---
#
# ## 📌 4.1 Graficar datos originales
#
# ```python
# plt.figure()
# plt.scatter(X_centered[:,0], X_centered[:,1])
# plt.title("Datos Centrados")
# plt.xlabel("x1")
# plt.ylabel("x2")
# plt.axhline(0)
# plt.axvline(0)
# plt.show()
# ```
#
# ---
#
# ## 📌 4.2 Dibujar autovectores
#
# ```python
# plt.figure()
# plt.scatter(X_centered[:,0], X_centered[:,1])
#
# for i in range(len(eigenvalues)):
#     vec = eigenvectors[:, i] * np.sqrt(eigenvalues[i]) * 3
#     plt.arrow(0, 0, vec[0], vec[1], head_width=0.2)
#
# plt.title("Autovectores (Direcciones Principales)")
# plt.axhline(0)
# plt.axvline(0)
# plt.show()
# ```
#
# Interpretación geométrica:
#
# * El autovector asociado al mayor autovalor indica la dirección de mayor varianza.
# * PCA es simplemente un cambio de base hacia esa dirección.
#
# ---
#
# ## 📌 4.3 Proyección sobre la primera componente
#
# ```python
# v1 = eigenvectors[:, np.argmax(eigenvalues)]
#
# Z = X_centered @ v1.reshape(-1,1)
#
# plt.figure()
# plt.scatter(Z, np.zeros_like(Z))
# plt.title("Datos proyectados en la primera componente principal")
# plt.show()
# ```
#
# Interpretación:
#
# Estamos proyectando sobre un subespacio de dimensión 1.
#
# Reducción de dimensión = restricción a un subespacio dominante.
#
# ---
#
# # 🧠 Discusión Final Teórica
#
# Conectar explícitamente:
#
# | Proceso de Datos | Álgebra Lineal           |
# | ---------------- | ------------------------ |
# | Datos            | Matriz en ℝⁿˣᵖ           |
# | Limpieza         | Restricción del espacio  |
# | Regresión        | Proyección ortogonal     |
# | PCA              | Descomposición espectral |
# | Visualización    | Cambio de base           |
#
# ---
#
# # 📘 Preguntas para el estudiante
#
# 1. ¿Qué condición garantiza que ( X^TX ) sea invertible?
# 2. ¿Por qué el residuo es ortogonal al espacio columna?
# 3. ¿Qué significa geométricamente que un autovalor sea muy pequeño?
# 4. ¿Cómo se interpreta la reducción de dimensión como restricción de subespacios?
#
# ---
#
# # 🚀 Extensión Avanzada (para Matemáticas Puras)
#
# Puedes agregar:
#
# * Demostración formal de existencia y unicidad de mínimos cuadrados.
# * Relación entre SVD y PCA.
# * Condición numérica y estabilidad.
# * Interpretación funcional como operador compacto.
#
# ---
#
# Si quieres, puedo ahora prepararte:
#
# * 📄 Una guía evaluable con rúbrica
# * 🧩 Un laboratorio tipo examen parcial
# * 📊 Una versión con SVD formal y demostración matemática completa
#
# ¿Cuál prefieres desarrollar?

# %% [markdown]
# # EXAMEN PARCIAL
#
# ## Álgebra Lineal Aplicada al Análisis de Datos
#
# **Universidad de Antioquia – Campus Caucasia**
#
# ---

# %% [markdown]
# # PARTE I — Estructura Lineal del Conjunto de Datos (25%)
#
# Sea:
#
# $$
# X =
# \begin{pmatrix}
# 1 & 2 & 3 \
# 2 & 4 & 6 \
# 1 & 1 & 1 \
# 0 & 1 & 2 \
# 3 & 6 & 9
# \end{pmatrix}
# $$
#
# ---

# %% [markdown]
# ## 1.1 (Teórico)
#
# ### a) Determine si las columnas son linealmente independientes.
#
# ### ✅ Solución
#
# Observamos:
#
# * Columna 2 = 2 × Columna 1 (en filas 1,2,5)
# * Columna 3 = 3 × Columna 1 (en filas 1,2,5)
#
# Aunque no es múltiplo exacto en todas las filas, podemos verificar formalmente con reducción por filas o rango.
#
# Conclusión:
#
# Las columnas son linealmente dependientes.
#
# ---

# %% [markdown]
# ### b) Calcule el rango de ( X ).
#
# ### ✅ Solución en Python
#
# ```python
# import numpy as np
#
# X = np.array([
#     [1,2,3],
#     [2,4,6],
#     [1,1,1],
#     [0,1,2],
#     [3,6,9]
# ])
#
# np.linalg.matrix_rank(X)
# ```
#
# Resultado esperado:
#
# [
# \text{rango}(X) = 2
# ]
#
# ---
#
# ### c) Describa geométricamente el espacio columna.
#
# ### ✅ Solución
#
# El espacio columna es un subespacio de ℝ⁵ de dimensión 2.
#
# Geométricamente:
#
# * Es un plano en ℝ⁵.
# * No llena todo ℝ⁵.
# * Existe redundancia en las variables.
#
# ---
#
# ## 📌 1.3
#
# Explique por qué la dependencia lineal implica que ( X^T X ) puede no ser invertible.
#
# ### ✅ Solución
#
# Si las columnas de ( X ) son dependientes, entonces:
#
# [
# \exists v \neq 0 \text{ tal que } Xv = 0
# ]
#
# Entonces:
#
# [
# X^T X v = X^T(0) = 0
# ]
#
# Por tanto, ( X^T X ) tiene núcleo no trivial ⇒ no es invertible.
#
# Conclusión:
#
# [
# \det(X^T X) = 0
# ]
#
# ---
#
# # 🔷 PARTE II — Regresión como Proyección Ortogonal (30%)
#
# Sea:
#
# [
# y =
# \begin{pmatrix}
# 1 \
# 2 \
# 1 \
# 0 \
# 3
# \end{pmatrix}
# ]
#
# ---
#
# ## 📌 2.1 (Formal)
#
# Explique por qué el problema de mínimos cuadrados consiste en proyectar ( y ) sobre Col(X).
#
# ### ✅ Solución
#
# Queremos minimizar:
#
# [
# |y - X\beta|^2
# ]
#
# Esto equivale a encontrar el vector en Col(X) más cercano a ( y ).
#
# Por teoría de proyecciones en espacios con producto interno:
#
# El vector más cercano es la proyección ortogonal.
#
# Por tanto:
#
# [
# \hat{y} = P_{\text{Col}(X)} y
# ]
#
# ---
#
# ## 📌 2.2 (Python)
#
# ```python
# y = np.array([1,2,1,0,3]).reshape(-1,1)
#
# beta_hat = np.linalg.pinv(X) @ y
# y_hat = X @ beta_hat
# residuo = y - y_hat
#
# beta_hat
# ```
#
# ---
#
# ## 📌 2.3
#
# Demuestre que:
#
# [
# X^T(y - X\hat{\beta}) = 0
# ]
#
# ### ✅ Solución
#
# Partimos de:
#
# [
# \hat{\beta} = (X^TX)^{-1}X^Ty
# ]
#
# Multiplicando:
#
# [
# X^T y - X^T X \hat{\beta} = 0
# ]
#
# Entonces:
#
# [
# X^T(y - X\hat{\beta}) = 0
# ]
#
# Interpretación:
#
# El residuo es ortogonal a cada columna de X.
#
# ---
#
# ## 📌 2.4 Interpretación geométrica
#
# ### ✅ Solución
#
# * ( y \in \mathbb{R}^5 )
# * ( \hat{y} \in \text{Col}(X) \subset \mathbb{R}^5 )
# * Residuo ( r \in \text{Col}(X)^\perp )
#
# Descomposición ortogonal:
#
# [
# \mathbb{R}^5 = \text{Col}(X) \oplus \text{Col}(X)^\perp
# ]
#
# ---
#
# # 🔷 PARTE III — PCA y Teorema Espectral (30%)
#
# ---
#
# ## 📌 3.2 Matriz de covarianza
#
# ```python
# np.random.seed(0)
#
# x1 = np.random.randn(200)
# x2 = 3*x1 + np.random.randn(200)*0.5
#
# X = np.column_stack((x1, x2))
# X_centered = X - np.mean(X, axis=0)
#
# cov = (X_centered.T @ X_centered) / len(X_centered)
# cov
# ```
#
# ---
#
# ## 📌 3.4 (Teórico)
#
# ### a) ¿Por qué es simétrica?
#
# ### ✅ Solución
#
# [
# \Sigma = \frac{1}{n} X^T X
# ]
#
# Entonces:
#
# [
# \Sigma^T = \frac{1}{n}(X^T X)^T = \frac{1}{n} X^T X = \Sigma
# ]
#
# ---
#
# ### b) ¿Qué garantiza el Teorema Espectral?
#
# ### ✅ Solución
#
# Como es simétrica real:
#
# * Autovalores reales
# * Base ortonormal de autovectores
# * Diagonalización ortogonal
#
# ---
#
# ### c) ¿Qué significa que un autovalor sea mayor?
#
# ### ✅ Solución
#
# Representa mayor varianza en esa dirección.
#
# Geométricamente:
#
# Los datos se extienden más en esa dirección.
#
# ---
#
# ## 📌 3.5 Reducción de dimensión
#
# ```python
# eigenvalues, eigenvectors = np.linalg.eig(cov)
#
# v1 = eigenvectors[:, np.argmax(eigenvalues)]
# Z = X_centered @ v1.reshape(-1,1)
# ```
#
# ### ✅ Solución conceptual
#
# Estamos proyectando sobre:
#
# [
# \text{span}{v_1}
# ]
#
# Subespacio de dimensión 1.
#
# Reducción de dimensión = restricción al subespacio dominante.
#
# ---
#
# # 🔷 PARTE IV — Visualización (15%)
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.figure()
# plt.scatter(X_centered[:,0], X_centered[:,1])
#
# for i in range(len(eigenvalues)):
#     vec = eigenvectors[:, i] * np.sqrt(eigenvalues[i]) * 3
#     plt.arrow(0,0,vec[0],vec[1])
#
# plt.axhline(0)
# plt.axvline(0)
# plt.show()
# ```
#
# ---
#
# ## Preguntas y Soluciones
#
# ### 1) ¿Qué dirección concentra mayor varianza?
#
# La asociada al mayor autovalor.
#
# ---
#
# ### 2) ¿Interpretación energética?
#
# La varianza es proporcional a la energía cuadrática del sistema.
#
# ---
#
# ### 3) Relación con SVD
#
# Si:
#
# [
# X = U \Sigma V^T
# ]
#
# Entonces:
#
# [
# X^T X = V \Sigma^2 V^T
# ]
#
# PCA y SVD son equivalentes estructuralmente.
#
# ---
#
# # 🔷 PARTE V — Profundización (Opcional)
#
# ### Demostrar fórmula con SVD
#
# Si:
#
# [
# X = U \Sigma V^T
# ]
#
# Entonces:
#
# [
# \hat{\beta} = V \Sigma^{-1} U^T y
# ]
#
# Porque:
#
# $$
# X^+ = V \Sigma^{-1} U^T
# $$
#
# Ventaja:
#
# Mayor estabilidad numérica cuando X es mal condicionada.
#
# ---
#
# # Cierre Conceptual
#
# Este parcial evalúa:
#
# * Rango y dependencia
# * Proyecciones ortogonales
# * Teorema espectral
# * Descomposición SVD
# * Interpretación geométrica
#
# ---

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12:
# * Martes 9-11 M:
# * Martes 2 a 6 PM: Álgebra Lineal.
# * Miércoles 9 a 11 M:
# * Jueves 8 a 12 M: Funamentos de Programación
# * Jueves 2 a 6 PM:
# * Viernes 8 - 12 M: Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.
# * Sábados 8-12: PIVU Puerto Libertador.

# %% [markdown]
# ## Monitores
# * José Luis Guerrero Guerra: .
# *

# %% [markdown]
# ## Referentes

# %% [markdown]
# [Libro guía Fundamentos de programación: Data Analysis with Python: Introducing NumPy, Pandas, Matplotlib, and Essential Elements of Python Programming (English Edition) [Kindle Edition]](https://read.amazon.com/?_encoding=UTF8&asin=B0BBB56L4X&consumptionLimitReached=false&deviceAccountIds=A1032123ZASLV79K77QP&hasMultimedia=false&requiredCapabilities=EBOK_PURCHASE_ALLOWED&ref=sr_rn_kfw) Este vínculo lo debo abrir con Chrome

# %% [markdown]
# * [Bergmann, J. (2012). *Flip Your Classroom.* (Aula Invertida).](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://blogs.ugto.mx/mdued/wp-content/uploads/sites/66/2022/11/Bergmann-y-Sams-Dale-la-vuelta-a-tu-clase.pdf)

# %% [markdown]
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)

# %% [markdown]
# * [Métodos numéricos usando python](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://librosoa.unam.mx/bitstream/handle/123456789/3416/MNPython.pdf?sequence=1&isAllowed=y)

# %% [markdown]
# * [Métodos numéricos usando python. Código fuente de todo el libro](https://github.com/jcjimenezb123/MNPython-Libro?tab=readme-ov-file#readme)

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)

# %% [markdown]
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html

# %% [markdown]
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)

# %% [markdown]
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)

# %% [markdown]
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)

# %% [markdown]
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)

# %% [markdown]
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)

# %% [markdown]
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [chatGPT](https://openai.com/blog/chatgpt)

# %% [markdown]
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Fundamentar Pedagógica y didácticamente mi propuesta de enseñanza

# %% [markdown]
# # Referentes en Didáctica de las Matemáticas y Pensamiento Computacional

# %% [markdown]
# ### 1. **Seymour Papert (1980, 1996)**
#
# * Padre del **constructionism**, con su obra *Mindstorms* (1980).
# * Plantea que la computadora no es solo una herramienta de cálculo, sino un **medio para pensar** y construir conocimiento matemático.
# * Sostiene que programar permite a los estudiantes interactuar con conceptos matemáticos de manera experimental.
# * Su lema central: *“Los niños no aprenden la matemática de las computadoras; aprenden matemáticas con las computadoras”*.
#   - Esto respalda tu idea de usar Python, LaTeX y Markdown como lenguajes que median la construcción de significados matemáticos.
#
# ---

# %% [markdown]
# # 2. **Alan H. Schoenfeld (1985, 1992)**

# %% [markdown]
# * Destaca la importancia de la **resolución de problemas** en la enseñanza de las matemáticas.
# * Su enfoque conecta con la idea de que el pensamiento computacional fomenta la **formulación, exploración y verificación de conjeturas** en ambientes como Jupyter Notebooks.
#   - Schoenfeld da soporte a que los lenguajes que propones sean **recursos didácticos** para generar entornos de resolución activa.
#
# ---

# %% [markdown]
# # 3. **Jean Piaget & Lev Vygotsky (constructivismo y socio-constructivismo)**

# %% [markdown]
# * Piaget: El conocimiento se construye a través de la acción y la experimentación.
# * Vygotsky: El aprendizaje se potencia con herramientas culturales y mediaciones.
#   - Jupyter, Python, LaTeX e inglés son **herramientas culturales del siglo XXI** que median el aprendizaje matemático.
#
# ---

# %% [markdown]
# ### 4. **Wing, Jeannette (2006)**
#
# * Introduce el término **pensamiento computacional** como una habilidad básica, tan fundamental como leer, escribir o hacer matemáticas.
# * Define que debe enseñarse desde la escuela hasta la universidad.
#   - Tu planteamiento de aplicarlo en **todos los niveles** y en **educación superior** tiene un sustento directo aquí.
#
# ---

# %% [markdown]
# ### 5. **NCTM (National Council of Teachers of Mathematics, 2000, 2014)**
#
# * En sus principios y estándares, plantea la necesidad de que los estudiantes desarrollen **fluidez tecnológica** en paralelo con la matemática.
# * Afirma que las herramientas tecnológicas permiten experimentar, representar y validar conceptos de manera más profunda.
#   - Esto legitima tu postura de que **no se trata de rivalizar con la enseñanza tradicional**, sino de enriquecerla con recursos.
#
# ---

# %% [markdown]
# # 6. **Duval, Raymond (1993, 2006)**
#
# * Con su teoría de los **registros de representación semiótica**, muestra que el aprendizaje matemático se fortalece cuando los estudiantes pueden cambiar entre registros (gráfico, simbólico, numérico, verbal, digital).
#   - Los lenguajes LaTeX, Markdown y Python son **nuevos registros de representación**, que complementan y no sustituyen al registro algebraico tradicional.
#
# ---

# %% [markdown]
# ### 7. **Godino, Juan D. y el Enfoque Ontosemiótico (EOS)**
#
# * Plantea que la matemática se aprende a través de **configuraciones de prácticas y significados**.
# * El uso de Jupyter y lenguajes computacionales enriquece esas prácticas al incluir **experimentación, validación y comunicación científica**.
#   - Esto refuerza tu idea de que estos lenguajes no compiten, sino que **aportan a la construcción de significados matemáticos más cercanos al mundo profesional**.
#
# ---

# %% [markdown]
# ### 8. **Sociedades Matemáticas y Computacionales**
#
# * **ACM (Association for Computing Machinery)** y **IEEE** han publicado directrices donde destacan que el pensamiento computacional debe ser transversal a todas las disciplinas.
# * En Latinoamérica, la **Sociedad Colombiana de Matemáticas Educativa (ASOCOLME)** también promueve la integración de tecnologías en la didáctica.
#
# ---

# %% [markdown]
# # Cómo integrar estos referentes con tu postura

# %% [markdown]
# 1. **Papert, Wing y Piaget-Vygotsky** sustentan que el pensamiento computacional debe enseñarse desde todos los niveles.
# 2. **Schoenfeld, Duval y Godino** muestran que estas herramientas enriquecen la comprensión matemática sin sustituir los enfoques tradicionales.
# 3. **NCTM, ACM y IEEE** legitiman que las matemáticas deben enseñarse con herramientas tecnológicas alineadas con el mundo laboral y científico.
#
# ---

# %% [markdown]
# # Frase integradora que puedes usar
#
# > “Siguiendo a Papert, Wing y Duval, concebimos el pensamiento computacional no como un accesorio, sino como un lenguaje cultural contemporáneo. Al incorporar Python, LaTeX, Markdown e inglés en la enseñanza de las matemáticas mediante entornos como Jupyter Notebooks, no competimos con los métodos tradicionales, sino que ampliamos los registros de representación y potenciamos el aprendizaje significativo, en sintonía con lo que requieren los profesionales del siglo XXI.”

# %% [markdown]
# # Línea argumentativa (Marco teórico)

# %% [markdown]
# El desarrollo del **pensamiento computacional** constituye hoy un eje fundamental en la educación matemática. Como lo plantea **Wing (2006)**, esta forma de razonamiento debe considerarse una competencia transversal y básica, al nivel de la lectura, la escritura y las matemáticas.

# %% [markdown]
# En consecuencia, fomentar su aprendizaje desde los niveles iniciales hasta la educación superior resulta indispensable para formar profesionales capaces de enfrentar los retos de la sociedad contemporánea.

# %% [markdown]
# En el campo de la didáctica de las matemáticas, **Papert (1980, 1996)** había anticipado esta necesidad al concebir las computadoras no como simples herramientas de cálculo, sino como **“objetos para pensar”**, capaces de favorecer la construcción activa de significados matemáticos a través de la programación.

# %% [markdown]
# Esta visión se alinea con el constructivismo de **Piaget**, que resalta el valor de la experimentación en el aprendizaje, y con la perspectiva socio-constructivista de **Vygotsky**, que otorga un papel central a las herramientas culturales en la mediación del conocimiento.

# %% [markdown]
# En este marco, el uso de entornos como **Jupyter Notebooks** y lenguajes como **Python, LaTeX, Markdown e inglés** no debe interpretarse como una rivalidad con la enseñanza tradicional de la matemática, sino como una **ampliación de los registros de representación** que describió **Duval (1993, 2006)**.

# %% [markdown]
# Según su teoría semiótica, el aprendizaje significativo se potencia cuando el estudiante logra traducir y articular distintos sistemas de representación: gráfico, algebraico, numérico, verbal y, en nuestro tiempo, digital.

# %% [markdown]
# De igual manera, el **Enfoque Ontosemiótico de Godino (2002, 2017)** muestra que los significados matemáticos emergen de prácticas diversas, lo que justifica la incorporación de estos lenguajes como recursos que enriquecen las configuraciones de práctica matemática, en sintonía con las exigencias de la investigación y la práctica profesional.

# %% [markdown]
# En el ámbito internacional, organizaciones como el **NCTM (2000, 2014)** han subrayado que la tecnología es esencial para la enseñanza y el aprendizaje de la matemática, dado que facilita la experimentación, la validación de conjeturas y la comunicación de ideas.

# %% [markdown]
# Asimismo, instancias como la **ACM** y el **IEEE** han señalado la importancia de desarrollar habilidades computacionales como requisito fundamental en la formación universitaria, tanto en el sector público como privado.

# %% [markdown]
# Por tanto, enseñar matemáticas integrando Python, LaTeX, Markdown e inglés en ambientes como Jupyter Notebooks contribuye a la formación de profesionales con **competencias científicas, comunicativas y tecnológicas**, capaces de comprender la matemática de manera interactiva y experimental, y de responder a las demandas del mundo laboral.

# %% [markdown]
# Esta integración, lejos de ser inadecuada, constituye un **puente entre la enseñanza académica y las necesidades de la sociedad**, fortaleciendo la pertinencia de los programas universitarios.
#
# ---

# %% [markdown]
# # Tabla de referentes en didáctica de las matemáticas y pensamiento computacional

# %% [markdown]
# | **Autor / Institución**         | **Aporte central**                                                                       | **Relevancia para tu postura**                                                            |
# | ------------------------------- | ---------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------- |
# | **Papert, S. (1980, 1996)**     | *Mindstorms*. La computadora como “objeto para pensar”; base del constructionism.        | Justifica la programación (Python) como medio para construir conocimiento matemático.     |
# | **Wing, J. (2006)**             | Introduce el concepto de **pensamiento computacional** como habilidad básica para todos. | Fundamenta que debe enseñarse desde la primaria hasta la universidad.                     |
# | **Schoenfeld, A. (1985, 1992)** | Enfoque en la **resolución de problemas** y procesos cognitivos en matemáticas.          | Apoya el uso de herramientas digitales para explorar y verificar conjeturas.              |
# | **Piaget, J.**                  | Constructivismo: el aprendizaje surge de la acción y la experimentación.                 | Refuerza la idea de aprender matemáticas de forma interactiva en Jupyter.                 |
# | **Vygotsky, L.**                | Socio-constructivismo: las herramientas culturales median el aprendizaje.                | Python, LaTeX y Markdown son **herramientas culturales contemporáneas**.                  |
# | **Duval, R. (1993, 2006)**      | Teoría de registros de representación semiótica.                                         | LaTeX, Markdown y Python son nuevos registros que enriquecen la comprensión matemática.   |
# | **Godino, J. D. (2002, 2017)**  | Enfoque Ontosemiótico de la Cognición Matemática.                                        | Los lenguajes digitales enriquecen las configuraciones de práctica matemática.            |
# | **NCTM (2000, 2014)**           | Principios y estándares: la tecnología es esencial en matemáticas.                       | Legitima el uso de Jupyter y lenguajes como recursos para experimentación y comunicación. |
# | **ACM / IEEE**                  | Lineamientos de competencias digitales y computacionales en educación superior.          | Respaldo internacional: el mercado laboral exige habilidades computacionales.             |
#
# ---

# %% [markdown]
# # Referencias en formato APA (7ª edición)

# %% [markdown]
# * ACM & IEEE Computer Society. (2013). *Computer Science Curricula 2013: Curriculum Guidelines for Undergraduate Degree Programs in Computer Science*. ACM Press. [https://doi.org/10.1145/2534860](https://doi.org/10.1145/2534860)

# %% [markdown]
# * Duval, R. (1993). *Registres de représentations sémiotiques et fonctionnement cognitif de la pensée*. Annales de didactique et de sciences cognitives, 5, 37–65.

# %% [markdown]
# * Duval, R. (2006). A cognitive analysis of problems of comprehension in a learning of mathematics. *Educational Studies in Mathematics, 61*(1-2), 103–131. [https://doi.org/10.1007/s10649-006-0400-z](https://doi.org/10.1007/s10649-006-0400-z)

# %% [markdown]
# * Godino, J. D., Batanero, C., & Font, V. (2007). The onto-semiotic approach to research in mathematics education. *ZDM Mathematics Education, 39*(1–2), 127–135. [https://doi.org/10.1007/s11858-006-0004-1](https://doi.org/10.1007/s11858-006-0004-1)

# %% [markdown]
# * Godino, J. D. (2017). El enfoque ontosemiótico de la cognición e instrucción matemática. *Revista Latinoamericana de Investigación en Matemática Educativa, 20*(1), 5–30. [https://doi.org/10.12802/relime.17.2011](https://doi.org/10.12802/relime.17.2011)

# %% [markdown]
# * National Council of Teachers of Mathematics. (2000). *Principles and Standards for School Mathematics*. Reston, VA: NCTM.

# %% [markdown]
# * National Council of Teachers of Mathematics. (2014). *Principles to Actions: Ensuring Mathematical Success for All*. Reston, VA: NCTM.
#
# * Papert, S. (1980). *Mindstorms: Children, Computers, and Powerful Ideas*. New York, NY: Basic Books.
#
# * Papert, S. (1996). *The Connected Family: Bridging the Digital Generation Gap*. Atlanta, GA: Longstreet Press.
#
# * Piaget, J. (1970). *Psychology and Epistemology: Towards a Theory of Knowledge*. New York, NY: Viking Press.
#
# * Schoenfeld, A. H. (1985). *Mathematical Problem Solving*. Orlando, FL: Academic Press.
#
# * Schoenfeld, A. H. (1992). Learning to think mathematically: Problem solving, metacognition, and sense-making in mathematics. In D. Grouws (Ed.), *Handbook of Research on Mathematics Teaching and Learning* (pp. 334–370). New York, NY: Macmillan.

# %% [markdown]
# * Vygotsky, L. S. (1978). *Mind in Society: The Development of Higher Psychological Processes*. Cambridge, MA: Harvard University Press.

# %% [markdown]
# * Wing, J. M. (2006). Computational thinking. *Communications of the ACM, 49*(3), 33–35. [https://doi.org/10.1145/1118178.1118215](https://doi.org/10.1145/1118178.1118215)
#
# ---

# %% [markdown]
# #  Estado del arte

# %% [markdown]
# El interés por integrar la tecnología en la enseñanza de las matemáticas tiene raíces en las propuestas de **Papert (1980, 1996)**, quien con su enfoque constructionista concibió la computadora como un “objeto para pensar”, capaz de mediar la construcción activa de significados matemáticos mediante la programación.

# %% [markdown]
# Esta perspectiva se enlaza con los planteamientos de **Piaget (1970)** y **Vygotsky (1978)**, quienes reconocieron la importancia de la experimentación y de las herramientas culturales en la formación del pensamiento.

# %% [markdown]
# Bajo esta mirada, el uso de entornos digitales no constituye una amenaza para la enseñanza tradicional de las matemáticas, sino un recurso que amplía las posibilidades de aprendizaje.

# %% [markdown]
# A comienzos del siglo XXI, la noción de **pensamiento computacional** introducida por **Wing (2006)** renovó el debate al proponer que esta competencia debía enseñarse de manera transversal desde los niveles iniciales hasta la educación superior, situándola al mismo nivel que la lectura, la escritura y las matemáticas.

# %% [markdown]
# Este enfoque se alinea con los planteamientos del **NCTM (2000, 2014)**, que destacó la tecnología como un componente esencial para la experimentación, la representación y la comunicación en matemáticas. En paralelo, aportes teóricos como la **teoría de registros de representación semiótica de Duval (1993, 2006)** y el **Enfoque Ontosemiótico de Godino (2007, 2017)** muestran que el aprendizaje matemático se enriquece al transitar entre múltiples sistemas de representación, incluyendo los digitales.

# %% [markdown]
# En el contexto actual, organizaciones como la **ACM** y el **IEEE** insisten en que las competencias computacionales son indispensables en la formación profesional, lo que refuerza la pertinencia de integrar lenguajes como **Python, LaTeX, Markdown e inglés** en ambientes como **Jupyter Notebooks** para la enseñanza universitaria de las matemáticas.

# %% [markdown]
# Así, el estado del arte evidencia un consenso creciente: lejos de ser un obstáculo, el pensamiento computacional y el uso de lenguajes digitales constituyen una vía para fortalecer la comprensión matemática, formar profesionales más competentes y responder a las demandas del mundo laboral y científico contemporáneo.
#
# ---

# %% [markdown]
# # Estado del arte con citas

# %% [markdown]
# El uso de la tecnología en la enseñanza de las matemáticas encuentra uno de sus pilares en **Papert (1980)**, quien afirmaba que *“los niños no aprenden sobre la computadora, aprenden con la computadora”* (p. 6).

# %% [markdown]
# En su visión, la programación se convierte en un medio para la construcción activa de significados matemáticos, idea que se enlaza con la epistemología genética de **Piaget (1970)**, quien sostuvo que *“el conocimiento se construye a través de la acción”* (p. 15), y con la perspectiva de **Vygotsky (1978)**, al señalar que *“toda función en el desarrollo cultural del niño aparece dos veces: primero en el plano social y después en el individual”* (p. 57).

# %% [markdown]
# Estos enfoques coinciden en otorgar a las herramientas culturales un papel esencial en la mediación del aprendizaje.

# %% [markdown]
# Posteriormente, **Wing (2006)** acuñó el término pensamiento computacional, definiéndolo como *“una habilidad fundamental para todos, no solo para los científicos de la computación”* (p. 33).

# %% [markdown]
# Esta autora subrayó que debía enseñarse de manera transversal, en paralelo con la lectura, la escritura y la matemática.

# %% [markdown]
# En la misma línea, el **NCTM (2000)** destacó que *“la tecnología es esencial en la enseñanza y el aprendizaje de las matemáticas; influye en la matemática que se enseña y mejora el aprendizaje de los estudiantes”* (p. 24).

# %% [markdown]
# Desde la didáctica de las matemáticas, **Duval (2006)** mostró que *“la comprensión matemática requiere la coordinación de al menos dos registros de representación diferentes”* (p. 107), lo que legitima la incorporación de registros digitales como LaTeX, Markdown y Python.

# %% [markdown]
# Por su parte, **Godino (2017)** planteó que *“el significado de un objeto matemático está constituido por el sistema de prácticas en el que interviene”* (p. 7), con lo cual la práctica digital se convierte en parte constitutiva del aprendizaje matemático.

# %% [markdown]
# Finalmente, organismos internacionales como la **ACM y el IEEE (2013)** enfatizan que *“las habilidades computacionales son esenciales para el ejercicio profesional en cualquier disciplina”* (p. 12).

# %% [markdown]
# De esta manera, se consolida un consenso: la enseñanza universitaria de las matemáticas debe integrar herramientas contemporáneas como **Jupyter Notebooks, Python, LaTeX, Markdown e inglés**, no para competir con la enseñanza tradicional, sino para **fortalecer la comprensión matemática, potenciar la comunicación científica y responder a las demandas del mundo laboral**.
#
# ---
