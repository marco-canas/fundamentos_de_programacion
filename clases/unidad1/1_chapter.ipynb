# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad1/1_chapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad1/1_chapter.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display
from PIL import Image

def generar_qr(url, version=1, box_size=10, border=4, fill_color="black", back_color="white"):
    """
    Genera y muestra un código QR para una URL dada en un Jupyter Notebook.
    
    Parámetros:
    - url: La URL para la cual generar el código QR
    - version: Tamaño del QR (1-40, donde 1 es el más pequeño)
    - box_size: Número de píxeles por cada "caja" del QR
    - border: Grosor del borde blanco alrededor del QR (en cajas)
    - fill_color: Color del código QR
    - back_color: Color de fondo del código QR
    
    Retorna:
    - Muestra el código QR directamente en el notebook
    - Retorna el objeto QR generado
    """
    # Configurar el generador de QR
    qr = qrcode.QRCode(
        version=version,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=box_size,
        border=border,
    )
    
    # Añadir la URL al QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color=fill_color, back_color=back_color)
    
    return img

# Ejemplo de uso:
# generar_qr("https://www.ejemplo.com")

# %%
url = "https://colab.research.google.com/github/marco-canas/fundamentos_de_programacion/blob/main/clases/unidad1/1_chapter.ipynb"
generar_qr(url)

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso de Fundamento de Programación:]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/algebra_y_trigonometria/blob/main/7_images/5_clase_3_2025-08-12_hora_11_04.jpg?raw=true'>

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/analisis_numerico.xlsx'
df = pd.read_excel(path)
df.index = np.arange(1, len(df) + 1)  # Cambiar el índice para que empiece en 1
df.head()
# Out:
#        Cedula                            Nombre  \
# 1  1067281024        ALVAREZ GOEZ DAIRO ESTEBAN
# 2  1041086439     CASTILLO SIERRA SHIRLIS SARAY
# 3  1045419649  ESPINOSA ESPINOSA LILIANA ANDREA
# 4  1040494191           GARCIA PADILLA JHONATAN
# 5  1038131529        HOYOS ARRIETA ELIECER JOSE
#
#                            Email   p1   q2  p2
# 1     dairo.alvarez1@udea.edu.co  2.8  NaN NaN
# 2   shirlis.castillo@udea.edu.co  1.7  NaN NaN
# 3  lilianaa.espinosa@udea.edu.co  1.7  NaN NaN
# 4   jhonatan.garcia1@udea.edu.co  3.0  NaN NaN
# 5        jose.hoyos2@udea.edu.co  5.0  3.5 NaN

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología de Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguajes Python, R; y con archivos Markdown y R-Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# # Y el enfoque de TRRS de Duval

# %% [markdown]
# # Estructura general para todas las clases
#
# Dame, por favor, un diseño de clase, con el enfoque: "Aula Invertida, STEAMS y De aprendizaje basado en problemas y proyectos(ABPP)" sobre: "El método de integración numérica llamado Sumas Izquierdas de Riemann ", siguiendo la estructura:
#
# 1. Título de la clase
#
# 2. Objetivos de aprendizaje que incluyan los indicadores del logro de estos objetivos.
#
# 3. Un mapa conceptual que resuma la clase elaborado en Graphviz de Python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:/Users/marco/Downloads"`. No olvides el parámetro `view = True` para el método `render()` de Graphviz. Para este mapa controla las superposiciones de los nodos con: graph [overlap=false]; // Elimina superposiciones (puede aumentar el espacio)
# graph [overlap="scalexy"]; // Escala el gráfico para evitar overlaps
# graph [overlap="compress"]; // Comprime el grafo sin overlaps
#
# 4. Dame elementos históricos y epistemológicos asociados a esta clase, pero contados como un cuento al estilo de un cuentero antioqueño en Colombia. Incluye imágenes de los protagonistas históricos de esta clase.
#
# 5. Contenido de la clase. Que el contenido parta de una situación real para llegar a una constitución del modelo matemático que represente tal situación real.
#
#
# 7. Actividades de aprendizaje: que incluya pruebas de escritorio para los algoritmos en forma verbal y seudo código, diagrama de flujo, y la implementación del algoritmo en lenguaje Python.
#
# 8. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 9.  Tarea o actividades de ejercitación y fijación.
#
# 10. Evaluación incluyendo diez proyectos, un ejemplo de quiz y un ejemplo de parcial.
#
# 11. Diseño de actividad de retroalimentación.
#
# 12. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 13.  Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas. Y Actividades para desarrollar la habilidad de la Tolerancia
#
# 14. Incluye 5 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de esta clase. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a Jeannette Wing (Desarrollo del pensamiento computacional). Dejame todos estos referentes ordenados de acuerdo a las normas APA. Incluye un referente en didáctica de la matemática que fundamente el uso del Enfoque de Aula Invertida, uno que fundamente el enfoque STEAMS y finalmente otro que fundamente el enfoque de Aprendizaje Basado en Problemas y Proyectos (ABPP)
#
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en Python.
#
# En particular utiliza para el diseño de clase a Numpy, Pandas, SymPy, Matplotlib.pyplot, Seaborn, Plotly, ipywidgets, matplotlib.animation y Jupyter Notebook.
#
# Cada vez que utilices `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la renderización de estas animaciones a través de Jupyter Notebook.
#
# No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dólar $ para que VS Code si me renderice estas expresiones del lenguaje latex. Cuando vallas a utilizar ipywidgets:
#
#
# * Obtenga el libro guía: Fundamentos de Programación, [aquí:](https://read.amazon.com/?_encoding=UTF8&asin=B0BBB56L4X&consumptionLimitReached=false&deviceAccountIds=A1032123ZASLV79K77QP&hasMultimedia=false&requiredCapabilities=EBOK_PURCHASE_ALLOWED&ref=sr_rn_kfw)
# * Obtenga el programa del curso de Fundamentos de programación [aquí](https://github.com/marco-canas/fundamentos_de_programacion/blob/main/programa/Programa_Fundamentos_Programacion.md)
#
# * El cronograma o clase  a clase de este curso lo puede obtener [aquí]()

# %% [markdown]
# # [Chapter 1 Introducing Python]()
#
# ## Contenido de esta clase:
#
# 1. Structure
# 2. Objectives
# 3. A brief history of Python
# 4. Versions of Python
# 5. Features of Python
#    - General purpose
#    - Interpreted
#    - High level
#    - Multiparadigm
#    - Open source
#    - Portable
#    - Extensible
#    - Embeddable/Integrated
#    - Interactive
#    - Dynamically typed
# 6. Python use cases
#    - Automation
#    - Web scraping
#    - Healthcare
#    - Finance and banking
#    - Data analytics
#    - AI/ML
# 7. Conclusion
# 8. Questions
# 9. Points to remember

# %% [markdown]
# # [Chapter 1 Introducing Python](https://read.amazon.com/?_encoding=UTF8&asin=B0BBB56L4X&consumptionLimitReached=false&deviceAccountIds=A1032123ZASLV79K77QP&hasMultimedia=false&requiredCapabilities=EBOK_PURCHASE_ALLOWED&ref=sr_rn_kfw)
#
# These days Python is getting more attention among developers, especially from data scientists, data analysts, and AI/ML practitioners. In this chapter, we will discuss the history, evaluation, and features of Python, due to which it is one of the most popular programming languages today. According to the latest TIOBE Programming Community Index (https://www.tiobe.com/tiobe-index/), Python is ranked first among the most popular programming languages of 2022.
#
# Actualmente, Python está atrayendo cada vez más la atención de los desarrolladores, especialmente de científicos de datos, analistas de datos y profesionales de IA/ML. En este capítulo, analizaremos su historia, evaluación y características, lo que lo convierte en uno de los lenguajes de programación más populares en la actualidad. Según el último Índice de la Comunidad de Programación TIOBE (https://www.tiobe.com/tiobe-index/), Python ocupa el primer puesto entre los lenguajes de programación más populares de 2022.

# %% [markdown]
# ## Contenido de esta clase:
#
# 1. Structure
#    In this chapter, we will discuss the following topics: A brief history of Python Different versions of Python Features of Python Use cases of Python Objectives After studying this chapter, you should be able to:
#
# En este capítulo, discutiremos los siguientes temas:
# * Una breve historia de Python
# * Diferentes versiones de Python
# * Características de Python
# * Casos de uso de Python

# %% [markdown]
# 2. Objectives
#
# Después de estudiar este capítulo, usted debería ser capaz de:
#
# * Obtenga información sobre el creador de Python
# * Obtenga información sobre la evaluación de Python
# * Discuta las características y casos de uso de Python

# %% [markdown]
# 3. A brief history of Python
#
# Python es un lenguaje de programación de propósito general y alto nivel; admite los paradigmas de programación procedimental, orientado a objetos y funcional.
#
# Python fue concebido por Guido van Rossum a finales de la década de 1980 en el Centrum Wiskunde & Informatica (CWI) de los Países Bajos como sucesor del lenguaje ABC.
#
# Python se lanzó inicialmente en 1991. Su nombre se debe al programa de televisión de la BBC Monty Python's Flying Circus, ya que a Guido le gustaba mucho este.

# %% [markdown]
# 4. Versions of Python
#
# La versión 1.0 de Python se lanzó en 1994; en 2000, se introdujo Python 2.0, y Python 3.0 (también llamado «Python 3000» o «Py3K») se lanzó en 2008.
#
# La mayoría de los proyectos de la industria utilizan actualmente Python 3.x. En este libro, utilizamos Python 3.8:

# %% [markdown]
# 5. Features of Python
#
# Aquí, veremos las diversas propiedades/características de Python, que lo hacen más popular entre todos los demás lenguajes de programación.

# %% [markdown]
#    # - General purpose
#
# Python es un lenguaje de programación de propósito general, lo que significa que se puede utilizar para crear cualquier tipo de programa informático. No está diseñado para un dominio específico, como SQL (para bases de datos) o HTML (para páginas web).
#
# Un lenguaje de programación que puede desarrollar diversas aplicaciones en distintos dominios, sin limitarse a su uso específico, se conoce como lenguaje de programación de propósito general. Python es un lenguaje de programación de propósito general, ya que permite desarrollar aplicaciones web, de escritorio, científicas, de análisis de datos, de IA/ML y muchas más en diversos dominios.

# %% [markdown]
#    # - Interpreted
#
# Python es un lenguaje interpretado, lo que significa que el código fuente de Python se ejecuta línea por línea. No es necesario compilar el código fuente antes de ejecutarlo. Un intérprete lee el código fuente y lo ejecuta directamente.
#
# Python es un lenguaje de programación interpretado, lo que significa que ejecuta el código línea por línea.

# %% [markdown]
#    - High level
#
# Python es un lenguaje de alto nivel, lo que significa que está más cerca del lenguaje humano y más alejado del lenguaje de la máquina. No es necesario preocuparse por los detalles de la gestión de la memoria y otros aspectos de bajo nivel al escribir código en Python.
#
# Python es un lenguaje de programación de alto nivel, como C, C++ y Java. Un lenguaje de programación de alto nivel es más legible y fácil de entender para los humanos, ya que se abstrae a lenguajes de máquina, que son más cercanos a la máquina y menos legibles para los humanos.

# %% [markdown]
#    # - Multiparadigm
#
# Python es un lenguaje de programación multiparadigma, lo que significa que admite varios paradigmas de programación, como la programación procedimental, orientada a objetos y funcional.
#
# El lenguaje de programación Python admite múltiples paradigmas de programación, lo que lo hace más potente y flexible para desarrollar soluciones a problemas complejos. Python admite la programación procedimental, pero también ofrece funciones de programación orientada a objetos, programación funcional y programación orientada a aspectos.

# %% [markdown]
#    # - Open source
#
# Python es un lenguaje de programación de código abierto, lo que significa que su código fuente está disponible públicamente y cualquiera puede contribuir a su desarrollo. La comunidad de Python es muy activa y contribuye constantemente al desarrollo del lenguaje.
#
# Python es un lenguaje de programación de código abierto, lo que significa que su código fuente está disponible públicamente y cualquiera puede contribuir a su desarrollo. Python es desarrollado y mantenido por la Python Software Foundation (PSF), una organización sin fines de lucro dedicada a promover y apoyar el lenguaje de programación Python y su comunidad.

# %% [markdown]
#    - Portable
#
# Python es un lenguaje de programación portátil, lo que significa que el código fuente de Python se puede ejecutar en diferentes plataformas sin modificaciones. Python es compatible con varios sistemas operativos, como Windows, macOS, Linux y Unix.

# %% [markdown]
#    - Extensible
#
# Python proporciona la interfaz para extender el código Python con otros lenguajes de programación como C, C++, etc. En Python, se crean diversas bibliotecas y módulos con C y C++.

# %% [markdown]
#    - Embeddable/Integrated
#
# Python se puede integrar en aplicaciones escritas en otros lenguajes de programación como C, C++, Java, etc. Python proporciona la interfaz para incrustar el intérprete de Python en aplicaciones escritas en otros lenguajes de programación.

# %% [markdown]
# #   - Interactive
#
# El modo interactivo de Python Shell ofrece la función Read, Eval Print, and Loop (REPL), que proporciona retroalimentación interactiva instantánea al usuario. Es una de las características que ha hecho que Python sea más popular entre los analistas y científicos de datos. Los pasos del proceso REPL son los siguientes: Read: toma la entrada del usuario. Eval: evalúa la entrada. Print: imprime el resultado. Loop: repite el proceso.

# %% [markdown]
#    - Dynamically typed
#
# Python es un lenguaje de programación dinámicamente tipado, lo que significa que no es necesario declarar el tipo de variable al crear una variable. El tipo de variable se determina en tiempo de ejecución. Python realiza la verificación de tipos en tiempo de ejecución, lo que significa que los errores de tipo se detectan durante la ejecución del programa.

# %% [markdown]
# 6. Python use cases
#
# Python es uno de los lenguajes de programación más populares y de más rápida evolución en la actualidad. Se utiliza desde la automatización de tareas manuales cotidianas hasta la implementación de IA. En esta sección del capítulo, analizamos cómo se utiliza Python para resolver nuestros problemas empresariales y sus aplicaciones.

# %% [markdown]
# #   - Automation
#
# Para la automatización, Python se usa ampliamente para escribir scripts, utilidades y herramientas de automatización. Por ejemplo, en las pruebas de automatización, los desarrolladores utilizan diversos frameworks de Python.
#
# Aquí tienes **ejemplos representativos de frameworks y librerías en Python para automatización de tareas**, organizados por **tipo de automatización**, con una breve explicación y ejemplos típicos de uso.
#
# ---
#
# ## 🔁 Automatización de tareas generales / scripting
#
# ### 1. **Click**
#
# 📌 *Framework para crear herramientas de línea de comandos (CLI)*
#
# * Ideal para automatizar flujos repetitivos desde la terminal.
# * Muy usado en ciencia de datos y DevOps.
#
# **Ejemplo de uso**
#
# * Scripts de limpieza de datos
# * Ejecución automatizada de notebooks
# * Procesos ETL simples
#
# ```python

# %%
import click

@click.command()
@click.option('--nombre', default='Mundo')
def saludar(nombre):
    click.echo(f'Hola {nombre}')

if __name__ == '__main__':
    saludar(args=[], standalone_mode=False)
# Out:
# Hola Mundo

# %% [markdown]
# # 2. **Invoke**
#
# 📌 *Automatización de tareas tipo Makefile en Python*
#
# * Muy útil para ejecutar comandos del sistema.
# * Similar a `fabric`, pero local.
#
# **Casos típicos**
#
# * Automatizar tests
# * Limpieza de proyectos
# * Despliegues locales

# %%
from invoke import task

@task
def limpiar(c):
    c.run("rm -rf __pycache__")

# %% [markdown]
# # Automatización web y scraping

# %% [markdown]
# ## 3. **Selenium**
#
# 📌 *Automatización de navegadores web*
#
# * Simula interacción humana con páginas web.
# * Ideal para páginas dinámicas (JavaScript).

# %% [markdown]
# **Usos**
#
# * Automatizar formularios
# * Pruebas funcionales
# * Descarga de información web
#
# ---

# %% [markdown]
# ### 4. **Playwright**
#
# 📌 *Automatización web moderna (más rápida y estable que Selenium)*
#
# * Soporta Chromium, Firefox y WebKit.
# * Muy usado hoy en testing y scraping avanzado.
#
# **Ejemplo**
#
# ```python
# from playwright.sync_api import sync_playwright
#
# with sync_playwright() as p:
#     browser = p.chromium.launch()
#     page = browser.new_page()
#     page.goto("https://example.com")
#     print(page.title())
# ```
#
# ---

# %% [markdown]
# ### 5. **Scrapy**
#
# 📌 *Framework especializado en web scraping*
#
# * Alto rendimiento
# * Manejo de pipelines, spiders y middlewares
#
# **Usos**
#
# * Recolección masiva de datos
# * Proyectos de ciencia de datos
# * Crawlers académicos
#
# ---

# %% [markdown]
# # Automatización de pruebas (testing)
#
# ## 6. **pytest**
#
# - *Framework de testing con automatización integrada*
#
# * Muy flexible
# * Se integra con CI/CD

# %% [markdown]
# **Ejemplo**

# %%
def test_suma():
    assert 2 + 2 == 4

# %%
test_suma()

# %%
assert 2 + 2 == 4

# %% [markdown]
# # 7. **Robot Framework**
#
# - *Framework de automatización basado en palabras clave*
#
# * Muy usado en QA
# * Ideal para equipos no técnicos
#
# **Ejemplo (formato texto)**
#
# ```text
# *** Test Cases ***
# Ejemplo
#     Abrir Navegador    https://example.com
# ```
#
# ---

# %% [markdown]
# # Automatización de tareas programadas (scheduling)
#
# ## 8. **APScheduler**
#
# - *Programador de tareas en Python*
#
# * Alternativa a `cron`
# * Permite tareas en memoria, BD o distribuidas

# %%
from apscheduler.schedulers.blocking import BlockingScheduler

def tarea():
    print("Ejecutando tarea")

sched = BlockingScheduler()
sched.add_job(tarea, 'interval', minutes=10)
sched.start()

# %% [markdown]
# # 9. **Celery**
#
# - *Framework de tareas asíncronas y distribuidas*
#
# * Ideal para procesamiento en segundo plano
# * Usa Redis o RabbitMQ
#
# **Usos**
#
# * Procesamiento de datos
# * Envío de correos
# * Pipelines de ML
#
# ---

# %% [markdown]
# # Automatización de archivos y sistemas
#
# ## 10. **Luigi**
#
# - *Automatización de pipelines de datos*
#
# * Desarrollado por Spotify
# * Controla dependencias entre tareas
#
# ---

# %% [markdown]
# # 11. **Airflow**
#
# - *Orquestación de flujos de trabajo (DAGs)*
#
# * Muy usado en ingeniería de datos
# * Ideal para ETL complejos
#
# ---

# %% [markdown]
# # Automatización de escritorio
#
# ## 12. **PyAutoGUI**
#
# - *Automatiza mouse y teclado*
#
# * Útil cuando no hay API ni acceso al código fuente
#
# **Ejemplos**
#
# * Automatizar Excel
# * Simular interacción con software legacy
#
# ---

# %% [markdown]
# # Resumen rápido
#
# | Tipo de automatización | Framework                    |
# | ---------------------- | ---------------------------- |
# | Scripts / CLI          | Click, Invoke                |
# | Web                    | Selenium, Playwright, Scrapy |
# | Testing                | pytest, Robot Framework      |
# | Tareas programadas     | APScheduler, Celery          |
# | Pipelines de datos     | Luigi, Airflow               |
# | Escritorio             | PyAutoGUI                    |

# %% [markdown]
#    - Web scraping
#
# Python se utiliza ampliamente para el web scraping, que es el proceso de extraer datos de sitios web. Las bibliotecas populares de Python para el web scraping incluyen BeautifulSoup, Scrapy y Selenium. Estas bibliotecas permiten a los desarrolladores extraer datos de páginas web y almacenarlos en formatos estructurados como CSV, JSON o bases de datos.

# %% [markdown]
#    - Healthcare
#
# Python se utiliza en el sector de la salud para analizar datos médicos, desarrollar modelos predictivos y crear aplicaciones de atención médica. Las bibliotecas populares de Python para la atención médica incluyen NumPy, Pandas, Scikit-learn y TensorFlow. Estas bibliotecas permiten a los desarrolladores analizar datos médicos, crear modelos predictivos y desarrollar aplicaciones de atención médica.

# %% [markdown]
#    - Finance and banking
#
# Python se utiliza en el sector financiero y bancario para analizar datos financieros, desarrollar modelos de riesgo y crear aplicaciones de comercio algorítmico. Las bibliotecas populares de Python para las finanzas incluyen NumPy, Pandas, Scikit-learn y TensorFlow. Estas bibliotecas permiten a los desarrolladores analizar datos financieros, crear modelos de riesgo y desarrollar aplicaciones de comercio algorítmico.

# %% [markdown]
#    - Data analytics
#
# Python se utiliza ampliamente para el análisis de datos, que es el proceso de examinar, limpiar y modelar datos para descubrir información útil. Las bibliotecas populares de Python para el análisis de datos incluyen NumPy, Pandas, Matplotlib y Seaborn. Estas bibliotecas permiten a los desarrolladores analizar datos, crear visualizaciones y descubrir información útil.

# %% [markdown]
#    - AI/ML
#
# Python se utiliza ampliamente para la inteligencia artificial (IA) y el aprendizaje automático (ML), que son subcampos de la informática que se centran en crear sistemas que pueden aprender y mejorar a partir de datos. Las bibliotecas populares de Python para IA/ML incluyen Scikit-learn, TensorFlow y PyTorch. Estas bibliotecas permiten a los desarrolladores crear modelos de IA/ML, entrenarlos con datos y hacer predicciones.

# %% [markdown]
# 7. Conclusion
#
# En este capítulo, hemos aprendido que Python es un lenguaje de programación interpretado de alto nivel y código abierto, compatible con los paradigmas procedimental, orientado a objetos y funcional. Se utiliza para desarrollar diversas aplicaciones (scripting, aplicaciones web, aplicaciones GUI de escritorio, utilidades de línea de comandos y herramientas). Obtendremos información sobre cómo Python se ha desarrollado y evolucionado a lo largo de los años. Tras completar este capítulo, comprenderá claramente la naturaleza del lenguaje de programación y sus aplicaciones. En el siguiente capítulo, aprenderá a configurar Python y su entorno de desarrollo para aprender sobre Python y el análisis de datos.

# %% [markdown]
# 8. Questions
#
# * ¿Qué es Python y por qué es tan popular?
# * ¿Quién desarrolló el lenguaje de programación Python?
# * ¿Es compatible Python con la programación orientada a objetos?
# * Enumera algunos casos de uso donde podemos usar la programación Python.
# * ¿Cuáles son las diferentes maneras de ejecutar un programa Python?
# * ¿Cuáles son las características de la programación en Python?

# %% [markdown]
# 9. Points to remember
#
# Guido van Rossum desarrolló Python y lo lanzó al público en 1991. Python es un lenguaje de programación de alto nivel, interpretado y de tipado dinámico. Es un lenguaje de programación multiparadigma. Gracias a REPEL interactivo, la creación de prototipos futuros es sencilla con Python. Python es fácil de aprender, pero dominarlo requiere tiempo.

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12:
# * Martes 9-11 M:
# * Martes 2 a 6 PM:
# * Miércoles 9 a 11 M:
# * Jueves 8-12 M:
# * Jueves 2 a 6 PM:
# * Viernes 8 - 12 M:
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# * Asesoría: Sábados de 8 a 12 en el aula que nos asigne la sección de medios y logística.

# %% [markdown]
# ## Monitores
# * José Luis Guerrero Guerra: .
# *

# %% [markdown]
# ## Referentes

# %% [markdown]
# [Libro guía Fundamentos de programación: Data Analysis with Python: Introducing NumPy, Pandas, Matplotlib, and Essential Elements of Python Programming (English Edition) [Kindle Edition]](https://read.amazon.com/?_encoding=UTF8&asin=B0BBB56L4X&consumptionLimitReached=false&deviceAccountIds=A1032123ZASLV79K77QP&hasMultimedia=false&requiredCapabilities=EBOK_PURCHASE_ALLOWED&ref=sr_rn_kfw)

# %% [markdown]
# * [Bergmann, J. (2012). *Flip Your Classroom.* (Aula Invertida).](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://blogs.ugto.mx/mdued/wp-content/uploads/sites/66/2022/11/Bergmann-y-Sams-Dale-la-vuelta-a-tu-clase.pdf)

# %% [markdown]
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)

# %% [markdown]
# * [Métodos numéricos usando python](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://librosoa.unam.mx/bitstream/handle/123456789/3416/MNPython.pdf?sequence=1&isAllowed=y)

# %% [markdown]
# * [Métodos numéricos usando python. Código fuente de todo el libro](https://github.com/jcjimenezb123/MNPython-Libro?tab=readme-ov-file#readme)

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)

# %% [markdown]
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html

# %% [markdown]
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)

# %% [markdown]
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)

# %% [markdown]
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)

# %% [markdown]
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)

# %% [markdown]
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)

# %% [markdown]
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [chatGPT](https://openai.com/blog/chatgpt)

# %% [markdown]
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Fundamentar Pedagógica y didácticamente mi propuesta de enseñanza
#
# ## Prompt
#
# Dame referentes en didáctica de las matemáticas que sustente mi creencia y perspectiva que piensa que el desarrollo del pensamiento computacional debe fomentarse desde todos los niveles de escolaridad, más aún en educación superior con el animo de desarrollar la capacidad de leer de manera interactiva y experimental y así, con los cuadernos Jupyter, la enseñanza de los lenguajes Latex, MarkDown, Python e inglés, aportar al desarrollo de los profesionales de nuestra Universidad sin rivalizar con la postura de enseñanza que piensa que es inadecuado presentar paralelamente en la enseñanza de las matemáticas, los lenguajes que menciono, que creo pueden contribuir al aprendizaje de una matemática de manera significativa, y más cercana a lo que la empresa privada y pública requiere de nuestros egresados.

# %% [markdown]
# Mi planteamiento tiene mucho sustento en la **didáctica de las matemáticas contemporánea** y en corrientes relacionadas con el **pensamiento computacional, la alfabetización digital y el aprendizaje significativo**. Estos son referentes y marcos conceptuales que pueden servir para  citar o usar y fortalecer mi perspectiva:
#
# ---

# %% [markdown]
# # Referentes en Didáctica de las Matemáticas y Pensamiento Computacional

# %% [markdown]
# ### 1. **Seymour Papert (1980, 1996)**
#
# * Padre del **constructionism**, con su obra *Mindstorms* (1980).
# * Plantea que la computadora no es solo una herramienta de cálculo, sino un **medio para pensar** y construir conocimiento matemático.
# * Sostiene que programar permite a los estudiantes interactuar con conceptos matemáticos de manera experimental.
# * Su lema central: *“Los niños no aprenden la matemática de las computadoras; aprenden matemáticas con las computadoras”*.
#   - Esto respalda tu idea de usar Python, LaTeX y Markdown como lenguajes que median la construcción de significados matemáticos.
#
# ---

# %% [markdown]
# # 2. **Alan H. Schoenfeld (1985, 1992)**
#
# * Destaca la importancia de la **resolución de problemas** en la enseñanza de las matemáticas.
# * Su enfoque conecta con la idea de que el pensamiento computacional fomenta la **formulación, exploración y verificación de conjeturas** en ambientes como Jupyter Notebooks.
#   - Schoenfeld da soporte a que los lenguajes que propones sean **recursos didácticos** para generar entornos de resolución activa.
#
# ---

# %% [markdown]
# # 3. **Jean Piaget & Lev Vygotsky (constructivismo y socio-constructivismo)**

# %% [markdown]
# * Piaget: El conocimiento se construye a través de la acción y la experimentación.
# * Vygotsky: El aprendizaje se potencia con herramientas culturales y mediaciones.
#   - Jupyter, Python, LaTeX e inglés son **herramientas culturales del siglo XXI** que median el aprendizaje matemático.
#
# ---

# %% [markdown]
# # 4. **Wing, Jeannette (2006)**
#
# * Introduce el término **pensamiento computacional** como una habilidad básica, tan fundamental como leer, escribir o hacer matemáticas.
# * Define que debe enseñarse desde la escuela hasta la universidad.
#   - Tu planteamiento de aplicarlo en **todos los niveles** y en **educación superior** tiene un sustento directo aquí.
#
# ---

# %% [markdown]
# # 5. **NCTM (National Council of Teachers of Mathematics, 2000, 2014)**
#
# * En sus principios y estándares, plantea la necesidad de que los estudiantes desarrollen **fluidez tecnológica** en paralelo con la matemática.
# * Afirma que las herramientas tecnológicas permiten experimentar, representar y validar conceptos de manera más profunda.
#   - Esto legitima tu postura de que **no se trata de rivalizar con la enseñanza tradicional**, sino de enriquecerla con recursos.
#
# ---

# %% [markdown]
# # 6. **Duval, Raymond (1993, 2006)**
#
# * Con su teoría de los **registros de representación semiótica**, muestra que el aprendizaje matemático se fortalece cuando los estudiantes pueden cambiar entre registros (gráfico, simbólico, numérico, verbal, digital).
#   - Los lenguajes LaTeX, Markdown y Python son **nuevos registros de representación**, que complementan y no sustituyen al registro algebraico tradicional.
#
# ---

# %% [markdown]
# ### 7. **Godino, Juan D. y el Enfoque Ontosemiótico (EOS)**
#
# * Plantea que la matemática se aprende a través de **configuraciones de prácticas y significados**.
# * El uso de Jupyter y lenguajes computacionales enriquece esas prácticas al incluir **experimentación, validación y comunicación científica**.
#   👉 Esto refuerza tu idea de que estos lenguajes no compiten, sino que **aportan a la construcción de significados matemáticos más cercanos al mundo profesional**.
#
# ---
#
# ### 8. **Sociedades Matemáticas y Computacionales**
#
# * **ACM (Association for Computing Machinery)** y **IEEE** han publicado directrices donde destacan que el pensamiento computacional debe ser transversal a todas las disciplinas.
# * En Latinoamérica, la **Sociedad Colombiana de Matemáticas Educativa (ASOCOLME)** también promueve la integración de tecnologías en la didáctica.
#
# ---

# %% [markdown]
# # Cómo integrar estos referentes con tu postura
#
# 1. **Papert, Wing y Piaget-Vygotsky** sustentan que el pensamiento computacional debe enseñarse desde todos los niveles.
# 2. **Schoenfeld, Duval y Godino** muestran que estas herramientas enriquecen la comprensión matemática sin sustituir los enfoques tradicionales.
# 3. **NCTM, ACM y IEEE** legitiman que las matemáticas deben enseñarse con herramientas tecnológicas alineadas con el mundo laboral y científico.
#
# ---

# %% [markdown]
# # Frase integradora que puedes usar
#
# > “Siguiendo a Papert, Wing y Duval, concebimos el pensamiento computacional no como un accesorio, sino como un lenguaje cultural contemporáneo. Al incorporar Python, LaTeX, Markdown e inglés en la enseñanza de las matemáticas mediante entornos como Jupyter Notebooks, no competimos con los métodos tradicionales, sino que ampliamos los registros de representación y potenciamos el aprendizaje significativo, en sintonía con lo que requieren los profesionales del siglo XXI.”
#
# ---
#
# ¿Quieres que te arme una **línea argumentativa redactada como marco teórico** (listo para tu artículo o propuesta), o prefieres que primero te organice una **tabla de referentes con citas clave** para que los tengas como insumo rápido?

# %% [markdown]
# Esta es una **línea argumentativa** como marco teórico (redacción académica), y una **tabla de referentes con citas clave** para respaldar la bibliografía.
#
# ---

# %% [markdown]
# # Línea argumentativa (Marco teórico)

# %% [markdown]
# El desarrollo del **pensamiento computacional** constituye hoy un eje fundamental en la educación matemática. Como lo plantea **Wing (2006)**, esta forma de razonamiento debe considerarse una competencia transversal y básica, al nivel de la lectura, la escritura y las matemáticas.

# %% [markdown]
# En consecuencia, fomentar su aprendizaje desde los niveles iniciales hasta la educación superior resulta indispensable para formar profesionales capaces de enfrentar los retos de la sociedad contemporánea.

# %% [markdown]
# En el campo de la didáctica de las matemáticas, **Papert (1980, 1996)** había anticipado esta necesidad al concebir las computadoras no como simples herramientas de cálculo, sino como **“objetos para pensar”**, capaces de favorecer la construcción activa de significados matemáticos a través de la programación.

# %% [markdown]
# Esta visión se alinea con el constructivismo de **Piaget**, que resalta el valor de la experimentación en el aprendizaje, y con la perspectiva socio-constructivista de **Vygotsky**, que otorga un papel central a las herramientas culturales en la mediación del conocimiento.

# %% [markdown]
# En este marco, el uso de entornos como **Jupyter Notebooks** y lenguajes como **Python, LaTeX, Markdown e inglés** no debe interpretarse como una rivalidad con la enseñanza tradicional de la matemática, sino como una **ampliación de los registros de representación** que describió **Duval (1993, 2006)**.

# %% [markdown]
# Según su teoría semiótica, el aprendizaje significativo se potencia cuando el estudiante logra traducir y articular distintos sistemas de representación: gráfico, algebraico, numérico, verbal y, en nuestro tiempo, digital.

# %% [markdown]
# De igual manera, el **Enfoque Ontosemiótico de Godino (2002, 2017)** muestra que los significados matemáticos emergen de prácticas diversas, lo que justifica la incorporación de estos lenguajes como recursos que enriquecen las configuraciones de práctica matemática, en sintonía con las exigencias de la investigación y la práctica profesional.

# %% [markdown]
# En el ámbito internacional, organizaciones como el **NCTM (2000, 2014)** han subrayado que la tecnología es esencial para la enseñanza y el aprendizaje de la matemática, dado que facilita la experimentación, la validación de conjeturas y la comunicación de ideas. Asimismo, instancias como la **ACM** y el **IEEE** han señalado la importancia de desarrollar habilidades computacionales como requisito fundamental en la formación universitaria, tanto en el sector público como privado.

# %% [markdown]
# Por tanto, enseñar matemáticas integrando Python, LaTeX, Markdown e inglés en ambientes como Jupyter Notebooks contribuye a la formación de profesionales con **competencias científicas, comunicativas y tecnológicas**, capaces de comprender la matemática de manera interactiva y experimental, y de responder a las demandas del mundo laboral.

# %% [markdown]
# Esta integración, lejos de ser inadecuada, constituye un **puente entre la enseñanza académica y las necesidades de la sociedad**, fortaleciendo la pertinencia de los programas universitarios.
#
# ---

# %% [markdown]
# # Tabla de referentes en didáctica de las matemáticas y pensamiento computacional

# %% [markdown]
# | **Autor / Institución**         | **Aporte central**                                                                       | **Relevancia para tu postura**                                                            |
# | ------------------------------- | ---------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------- |
# | **Papert, S. (1980, 1996)**     | *Mindstorms*. La computadora como “objeto para pensar”; base del constructionism.        | Justifica la programación (Python) como medio para construir conocimiento matemático.     |
# | **Wing, J. (2006)**             | Introduce el concepto de **pensamiento computacional** como habilidad básica para todos. | Fundamenta que debe enseñarse desde la primaria hasta la universidad.                     |
# | **Schoenfeld, A. (1985, 1992)** | Enfoque en la **resolución de problemas** y procesos cognitivos en matemáticas.          | Apoya el uso de herramientas digitales para explorar y verificar conjeturas.              |
# | **Piaget, J.**                  | Constructivismo: el aprendizaje surge de la acción y la experimentación.                 | Refuerza la idea de aprender matemáticas de forma interactiva en Jupyter.                 |
# | **Vygotsky, L.**                | Socio-constructivismo: las herramientas culturales median el aprendizaje.                | Python, LaTeX y Markdown son **herramientas culturales contemporáneas**.                  |
# | **Duval, R. (1993, 2006)**      | Teoría de registros de representación semiótica.                                         | LaTeX, Markdown y Python son nuevos registros que enriquecen la comprensión matemática.   |
# | **Godino, J. D. (2002, 2017)**  | Enfoque Ontosemiótico de la Cognición Matemática.                                        | Los lenguajes digitales enriquecen las configuraciones de práctica matemática.            |
# | **NCTM (2000, 2014)**           | Principios y estándares: la tecnología es esencial en matemáticas.                       | Legitima el uso de Jupyter y lenguajes como recursos para experimentación y comunicación. |
# | **ACM / IEEE**                  | Lineamientos de competencias digitales y computacionales en educación superior.          | Respaldo internacional: el mercado laboral exige habilidades computacionales.             |
#
# ---

# %% [markdown]
# # Referencias en formato APA (7ª edición)

# %% [markdown]
# * ACM & IEEE Computer Society. (2013). *Computer Science Curricula 2013: Curriculum Guidelines for Undergraduate Degree Programs in Computer Science*. ACM Press. [https://doi.org/10.1145/2534860](https://doi.org/10.1145/2534860)

# %% [markdown]
# * Duval, R. (1993). *Registres de représentations sémiotiques et fonctionnement cognitif de la pensée*. Annales de didactique et de sciences cognitives, 5, 37–65.

# %% [markdown]
# * Duval, R. (2006). A cognitive analysis of problems of comprehension in a learning of mathematics. *Educational Studies in Mathematics, 61*(1-2), 103–131. [https://doi.org/10.1007/s10649-006-0400-z](https://doi.org/10.1007/s10649-006-0400-z)

# %% [markdown]
# * Godino, J. D., Batanero, C., & Font, V. (2007). The onto-semiotic approach to research in mathematics education. *ZDM Mathematics Education, 39*(1–2), 127–135. [https://doi.org/10.1007/s11858-006-0004-1](https://doi.org/10.1007/s11858-006-0004-1)
#
# * Godino, J. D. (2017). El enfoque ontosemiótico de la cognición e instrucción matemática. *Revista Latinoamericana de Investigación en Matemática Educativa, 20*(1), 5–30. [https://doi.org/10.12802/relime.17.2011](https://doi.org/10.12802/relime.17.2011)
#
# * National Council of Teachers of Mathematics. (2000). *Principles and Standards for School Mathematics*. Reston, VA: NCTM.
#
# * National Council of Teachers of Mathematics. (2014). *Principles to Actions: Ensuring Mathematical Success for All*. Reston, VA: NCTM.
#
# * Papert, S. (1980). *Mindstorms: Children, Computers, and Powerful Ideas*. New York, NY: Basic Books.
#
# * Papert, S. (1996). *The Connected Family: Bridging the Digital Generation Gap*. Atlanta, GA: Longstreet Press.
#
# * Piaget, J. (1970). *Psychology and Epistemology: Towards a Theory of Knowledge*. New York, NY: Viking Press.
#
# * Schoenfeld, A. H. (1985). *Mathematical Problem Solving*. Orlando, FL: Academic Press.
#
# * Schoenfeld, A. H. (1992). Learning to think mathematically: Problem solving, metacognition, and sense-making in mathematics. In D. Grouws (Ed.), *Handbook of Research on Mathematics Teaching and Learning* (pp. 334–370). New York, NY: Macmillan.
#
# * Vygotsky, L. S. (1978). *Mind in Society: The Development of Higher Psychological Processes*. Cambridge, MA: Harvard University Press.
#
# * Wing, J. M. (2006). Computational thinking. *Communications of the ACM, 49*(3), 33–35. [https://doi.org/10.1145/1118178.1118215](https://doi.org/10.1145/1118178.1118215)
#
# ---

# %% [markdown]
# Con estas referencias ya tienes un **marco bibliográfico sólido y reconocido internacionalmente**, que respalda tu propuesta de fomentar el pensamiento computacional y el uso de lenguajes (Python, LaTeX, Markdown, inglés) en la enseñanza de las matemáticas en tu universidad.

# %% [markdown]
# #  Estado del arte

# %% [markdown]
# El interés por integrar la tecnología en la enseñanza de las matemáticas tiene raíces en las propuestas de **Papert (1980, 1996)**, quien con su enfoque constructionista concibió la computadora como un “objeto para pensar”, capaz de mediar la construcción activa de significados matemáticos mediante la programación.

# %% [markdown]
# Esta perspectiva se enlaza con los planteamientos de **Piaget (1970)** y **Vygotsky (1978)**, quienes reconocieron la importancia de la experimentación y de las herramientas culturales en la formación del pensamiento.

# %% [markdown]
# Bajo esta mirada, el uso de entornos digitales no constituye una amenaza para la enseñanza tradicional de las matemáticas, sino un recurso que amplía las posibilidades de aprendizaje.

# %% [markdown]
# A comienzos del siglo XXI, la noción de **pensamiento computacional** introducida por **Wing (2006)** renovó el debate al proponer que esta competencia debía enseñarse de manera transversal desde los niveles iniciales hasta la educación superior, situándola al mismo nivel que la lectura, la escritura y las matemáticas.

# %% [markdown]
# Este enfoque se alinea con los planteamientos del **NCTM (2000, 2014)**, que destacó la tecnología como un componente esencial para la experimentación, la representación y la comunicación en matemáticas.

# %% [markdown]
# En paralelo, aportes teóricos como la **teoría de registros de representación semiótica de Duval (1993, 2006)** y el **Enfoque Ontosemiótico de Godino (2007, 2017)** muestran que el aprendizaje matemático se enriquece al transitar entre múltiples sistemas de representación, incluyendo los digitales.

# %% [markdown]
# En el contexto actual, organizaciones como la **ACM** y el **IEEE** insisten en que las competencias computacionales son indispensables en la formación profesional, lo que refuerza la pertinencia de integrar lenguajes como **Python, LaTeX, Markdown e inglés** en ambientes como **Jupyter Notebooks** para la enseñanza universitaria de las matemáticas.

# %% [markdown]
# Así, el estado del arte evidencia un consenso creciente: lejos de ser un obstáculo, el pensamiento computacional y el uso de lenguajes digitales constituyen una vía para fortalecer la comprensión matemática, formar profesionales más competentes y responder a las demandas del mundo laboral y científico contemporáneo.
#
# ---

# %% [markdown]
# # Estado del arte con citas

# %% [markdown]
# El uso de la tecnología en la enseñanza de las matemáticas encuentra uno de sus pilares en **Papert (1980)**, quien afirmaba que *“los niños no aprenden sobre la computadora, aprenden con la computadora”* (p. 6).

# %% [markdown]
# En su visión, la programación se convierte en un medio para la construcción activa de significados matemáticos, idea que se enlaza con la epistemología genética de **Piaget (1970)**, quien sostuvo que *“el conocimiento se construye a través de la acción”* (p. 15), y con la perspectiva de **Vygotsky (1978)**, al señalar que *“toda función en el desarrollo cultural del niño aparece dos veces: primero en el plano social y después en el individual”* (p. 57).

# %% [markdown]
# Estos enfoques coinciden en otorgar a las herramientas culturales un papel esencial en la mediación del aprendizaje.

# %% [markdown]
# Posteriormente, **Wing (2006)** acuñó el término pensamiento computacional, definiéndolo como *“una habilidad fundamental para todos, no solo para los científicos de la computación”* (p. 33).

# %% [markdown]
# Esta autora subrayó que debía enseñarse de manera transversal, en paralelo con la lectura, la escritura y la matemática.

# %% [markdown]
# En la misma línea, el **NCTM (2000)** destacó que *“la tecnología es esencial en la enseñanza y el aprendizaje de las matemáticas; influye en la matemática que se enseña y mejora el aprendizaje de los estudiantes”* (p. 24).

# %% [markdown]
# Desde la didáctica de las matemáticas, **Duval (2006)** mostró que *“la comprensión matemática requiere la coordinación de al menos dos registros de representación diferentes”* (p. 107), lo que legitima la incorporación de registros digitales como LaTeX, Markdown y Python.

# %% [markdown]
# Por su parte, **Godino (2017)** planteó que *“el significado de un objeto matemático está constituido por el sistema de prácticas en el que interviene”* (p. 7), con lo cual la práctica digital se convierte en parte constitutiva del aprendizaje matemático.

# %% [markdown]
# Finalmente, organismos internacionales como la **ACM y el IEEE (2013)** enfatizan que *“las habilidades computacionales son esenciales para el ejercicio profesional en cualquier disciplina”* (p. 12).

# %% [markdown]
# De esta manera, se consolida un consenso: la enseñanza universitaria de las matemáticas debe integrar herramientas contemporáneas como **Jupyter Notebooks, Python, LaTeX, Markdown e inglés**, no para competir con la enseñanza tradicional, sino para **fortalecer la comprensión matemática, potenciar la comunicación científica y responder a las demandas del mundo laboral**.
#
# ---
