# %% [markdown]
# # Punto 1: Modelado de Depreciación de Activos y Estética Básica (20 puntos)
#
# **Enunciado:**
# En contabilidad y finanzas minoristas, el valor de un activo tecnológico en una tienda tiende a decaer exponencialmente debido a la obsolescencia. Grafica la función $f(t) = e^{-0.2t}$ que representa la tasa de valor residual del activo en función del tiempo $t$, en un intervalo de $t$ desde $0$ hasta $15$ meses.
#
# **Requerimientos del gráfico:**
#
# * Utiliza una línea de color azul con un estilo continuo, un grosor de 3.
# * Añade un título descriptivo (ej. "Curva de Depreciación Exponencial de Activos Tecnológicos").
# * Coloca etiquetas claras en los ejes: Eje $X$ ("Tiempo (meses)") y Eje $Y$ ("Porcentaje de Valor Residual").
# * Activa la cuadrícula de fondo utilizando líneas de puntos finos (estilo `":"`).
# * Añade una leyenda que describa la curva matemática utilizando el parámetro `label` de la función `plot()`.

# %% [markdown]
# # Punto 2: Comparación de Métricas Comerciales mediante Subgráficos (20 puntos)
#
# **Enunciado:**
# El equipo de inventarios de una tienda retail quiere comparar el rendimiento de ventas durante una jornada de descuento de 6 horas: el número de "Transacciones Totales" y los "Ingresos por Hora" generados. Crea una sola figura con dos subgráficos dispuestos verticalmente (2 filas, 1 columna).
#
# * **Horas del evento:** `['H1', 'H2', 'H3', 'H4', 'H5', 'H6']`
# * **Transacciones Totales (unidades):** `[15, 22, 45, 58, 32, 14]`
# * **Ingresos por Hora (USD):** `[120, 250, 680, 890, 410, 180]`
#
# **Requerimientos de los subgráficos:**
#
# * El subgráfico superior debe mostrar las Transacciones Totales con un gráfico de líneas de color verde y marcadores cuadrados (`s`).
# * El subgráfico inferior debe mostrar los Ingresos por Hora con un gráfico de líneas de color rojo y marcadores circulares (`o`).
# * Cada subgráfico debe contar de forma obligatoria con su propio título, etiquetas en ambos ejes y cuadrícula.
# * Configura un título principal (`suptitle`) en la parte superior para toda la imagen (ej. "Monitoreo de Operaciones y Ventas Retail").

# %% [markdown]
# # Punto 3: Fase de Auditoría e Inspección de Calidad (Diagnóstico)
#
# **Consigna para el estudiante:** Carga el archivo `ventas_retail.csv` utilizando la librería `pandas`. Realiza una inspección técnica inicial utilizando los métodos `.info()`, `.describe()`, `.isnull().sum()`, y `value_counts()`.
#
# 1. Liste para cada variable del dataset: la naturaleza de la variable (cuantitativa, cualitativa), tipo de variable cuantitativa, y tipo de variable cualitativa o categórica.
#
# 2. Redacta un párrafo en una celda *Markdown* detallando **tres anomalías o inconsistencias** que encontraste en los datos puros (*raw data*) y explica por qué representan un problema para un análisis estadístico válido.
#
# 3. Identifica explícitamente cuáles variables son **cualitativas (categóricas)** y cuáles son **cuantitativas (numéricas)**.
#
# * **¿Qué evalúa esta actividad?:** La capacidad de reconocer tipos de variables y detectar errores de digitación, valores faltantes o nulos, y valores fuera de límites lógicos (outliers).

# %% [markdown]
# # Punto 4: Agregación y Resumen de Datos
#
#
# * Base de datos: monitoreo_y_gestion.db
#
# * archivo .csv: ventas_retail.csv
#
# **Sentencias a evaluar:** `SELECT`, `FROM`, `WHERE` y `GROUP BY`
#
# **Enunciado:** La gerencia comercial de la tienda está realizando un estudio del margen operativo en sus sucursales. Escribe una consulta en SQL que muestre la `Categoria` del producto y el **precio unitario promedio** (utiliza la función de agregación `AVG()`) de los artículos, agrupados por su categoría.

# %% [markdown]
# Sin embargo, para evitar sesgos por productos de liquidación o descontinuados, la consulta debe incluir **únicamente** a los productos que tengan un `Stock_Disponible` mayor o igual a 20 unidades.
#
# * **Celda de Código SQL:**

# %% [markdown]
# # Punto 5: Restricción y Ranking de Resultados (15 Puntos)
#
# Base de datos: monitoreo_y_gestion.db
#
# archivo .csv: ventas_retail.csv
#
# **Sentencias a evaluar:** `SELECT`, `FROM`, `WHERE`, `GROUP BY`, `ORDER BY` y `LIMIT`
#
# **Enunciado:** El departamento de finanzas corporativas desea encontrar los mayores volúmenes de inversión en stock en las sedes con mayor afluencia. Escribe una consulta en SQL que agrupe las transacciones por la zona de la `Sucursal` y calcule el promedio de `Stock_Disponible`. Aplica las siguientes restricciones en orden:
#
# 1. Filtra para que solo se evalúen los artículos con un `Precio_Unitario` premium o de alta gama (mayor o igual a 150.0).
# 2. Ordena los resultados de manera descendente (`DESC`) según el promedio de stock calculado.
# 3. Limita la salida para mostrar **únicamente el primer registro** (la sucursal con el promedio de inventario disponible más alto).
