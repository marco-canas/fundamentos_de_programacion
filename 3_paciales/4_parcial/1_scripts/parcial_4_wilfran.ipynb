# %% [markdown]
# # Punto 1: Modelado de Crecimiento Biológico y Estética Básica (20 puntos)
#
# **Enunciado:**
# En ecología, el crecimiento de una población bacteriana en un entorno cerrado con recursos limitados sigue una curva logística. Grafica la función $f(t) = \frac{1}{1 + e^{-t}}$ que representa la población en función del tiempo $t$, en un intervalo de $t$ desde $0$ hasta $15$ horas.
#
# **Requerimientos del gráfico:**
#
# * Utiliza una línea de color verde con un estilo continuo, un grosor de 3.
# * Añade un título descriptivo (ej. "Curva de Crecimiento Logístico de Población").
# * Coloca etiquetas claras en los ejes: Eje $X$ ("Tiempo (horas)") y Eje $Y$ ("Número de Individuos").
# * Activa la cuadrícula de fondo utilizando líneas de puntos finos (estilo `":"`).
# * Añade una leyenda que describa la curva matemática utilizando el parámetro `label` de la función `plot()`.

# %% [markdown]
# # Punto 2: Comparación de Métricas Web mediante Subgráficos (20 puntos)
#
# **Enunciado:**
# El equipo de marketing de una plataforma de streaming quiere comparar el comportamiento de dos métricas clave durante una jornada de ofertas de 6 horas: el número de "Usuarios Activos" y las "Suscripciones Premium" realizadas. Crea una sola figura con dos subgráficos dispuestos verticalmente (2 filas, 1 columna).
#
# * **Horas del evento:** `['H1', 'H2', 'H3', 'H4', 'H5', 'H6']`
# * **Usuarios Activos (miles):** `[10, 15, 35, 42, 28, 12]`
# * **Suscripciones Nuevas:** `[50, 80, 240, 310, 150, 60]`
#
# **Requerimientos de los subgráficos:**
#
# * El subgráfico superior debe mostrar los Usuarios Activos con un gráfico de líneas de color cian y marcadores cuadrados (`s`).
# * El subgráfico inferior debe mostrar las Suscripciones Nuevas con un gráfico de líneas de color magenta y marcadores circulares (`o`).
# * Cada subgráfico debe contar de forma obligatoria con su propio título, etiquetas en ambos ejes y cuadrícula.
# * Configura un título principal (`suptitle`) en la parte superior para toda la imagen (ej. "Monitoreo del Tráfico y Conversiones").

# %% [markdown]
# # Punto 3: Fase de Auditoría e Inspección de Calidad (Diagnóstico)
#
# **Consigna para el estudiante:** Carga el archivo `rendimiento_estudiantes.csv` utilizando la librería `pandas`. Realiza una inspección técnica inicial utilizando los métodos `.info()`, `.describe()`, `.isnull().sum()`, y `value_counts()`.
#
# 1. Liste para cada variable del dataset: la naturaleza de la variable (cuantitativa, cualitativa), tipo de variable cuantitativa, y tipo de variable cualitativa o categórica.
#
# 2. Redacta un párrafo en una celda *Markdown* detallando **tres anomalías o inconsistencias** que encontraste en los datos puros (*raw data*) y explica por qué representan un problema para un análisis estadístico válido.
#
# 3. Identifica explícitamente cuáles variables son **cualitativas (categóricas)** y cuáles son **cuantitativas (numéricas)**.
#
# * **¿Qué evalúa esta actividad?:** La capacidad de reconocer tipos de variables y detectar errores de digitación, valores faltantes o nulos, y valores fuera de límites lógicos (outliers).

# %% [markdown]
# # Punto 4: Agregación y Resumen de Datos
#
#
# * Base de datos: monitoreo_y_gestion.db
#
# * archivo .csv:  rendimiento_estudiantes.csv
#
# **Sentencias a evaluar:** `SELECT`, `FROM`, `WHERE` y `GROUP BY`
#
# **Enunciado:** La decanatura de la facultad está realizando un estudio comparativo del rendimiento académico. Escribe una consulta en SQL que muestre el `Género` y la **nota final promedio** (utiliza la función de agregación `AVG()`) de los estudiantes, agrupados por su género.

# %% [markdown]
# Sin embargo, para evitar sesgos por inasistencia, la consulta debe incluir **únicamente** a los estudiantes que tengan una `Asistencia_Porcentaje` mayor o igual a 80.
#
# * **Celda de Código SQL:**

# %% [markdown]
# # Punto 5: Restricción y Ranking de Resultados (15 Puntos)
#
# Base de datos: monitoreo_y_gestion.db
#
# archivo .csv: rendimiento_estudiantes.csv
#
# **Sentencias a evaluar:** `SELECT`, `FROM`, `WHERE`, `GROUP BY`, `ORDER BY` y `LIMIT`
#
# **Enunciado:** El comité de becas de excelencia académica desea encontrar los mejores promedios de horas de estudio invertidas en los estratos más necesitados. Escribe una consulta en SQL que agrupe a los estudiantes por su nivel `Socioeconómico` y calcule el promedio de `Horas_Estudio_Semana`. Aplica las siguientes restricciones en orden:
#
# 1. Filtra para que solo se evalúe a los estudiantes con una `Nota_Final` sobresaliente (mayor o igual a 4.0).
# 2. Ordena los resultados de manera descendente (`DESC`) según el promedio de horas calculado.
# 3. Limita la salida para mostrar **únicamente el primer registro** (el estrato con el promedio de estudio más alto).
