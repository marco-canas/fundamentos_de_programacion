# %%
(1,2)+(3,)
# Out:
# (1, 2, 3)

# %%
(2**3)**2
# Out:
# 64

# %%
a = [1,2]
b = a
a is b
# Out:
# True

# %%
'a' in {'c':1, 'b':2}
# Out:
# False

# %%
x = 1
x=x+1
x+=1
x
# Out:
# 3

# %%
x = 1500
1500==x
# Out:
# True

# %%
x is 1500
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\marco\AppData\Local\Temp\ipykernel_14816\1277341604.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   x is 1500
# False

# %%
a = [1,2,3]
b = [1,2,3]

# %%
id(a), id(b)
# Out:
# (2520218402944, 2520219655808)

# %%
a = [1,2,3]
b = a
id(a)==id(b)
# Out:
# True

# %%
x = 1
y = 1
x is y
# Out:
# True

# %%
x = 'marco'
y = 'marco'
y is x
# Out:
# True

# %%
nota1 = 3.5
nota2 = 4.0
nota3 = 2.8

promedio = (nota1 + nota2 + nota3 )/ 3

aprueba = promedio >= 3.0

print(f"Promedio: {round(promedio, 1)}")
print("Aprueba:", aprueba)
# Out:
# Promedio: 3.4
# Aprueba: True

# %%
def hipotenusa(cateto_1, cateto_2 = 3):
    return (cateto_1**2+cateto_2**2)**(1/2)

# %%
hipotenusa()
# Out:
# 8.54400374531753

# %%
def registrar_intento(usuario, historial = []):
    historial.append(usuario)
    return historial

# %%
print(registrar_intento('marco'))
print(registrar_intento('wilfran'))
# Out:
# ['marco']
# ['marco', 'wilfran']

# %%
lecturas = [21.5, 22.0, None, 23.4, 24.1, None, 20.8, 19.9, None, 25.0]

# %%
lecturas_limpias = [l for l in lecturas if l is not None] 
lecturas_limpias
# Out:
# [21.5, 22.0, 23.4, 24.1, 20.8, 19.9, 25.0]

# %%
promedio = sum(lecturas_limpias)/len(lecturas_limpias)
promedio
# Out:
# 22.385714285714283

# %%
max(lecturas_limpias)
# Out:
# 25.0

# %%
min(lecturas_limpias)
# Out:
# 19.9

# %%
lecturas_limpias[0] = 42

# %%
lecturas_limpias
# Out:
# [42, 22.0, 23.4, 24.1, 20.8, 19.9, 25.0]

# %%
tupla_lecturas = tuple(lecturas_limpias)

# %%
tupla_lecturas
# Out:
# (42, 22.0, 23.4, 24.1, 20.8, 19.9, 25.0)

# %%
tupla_lecturas[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 tupla_lecturas[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
id(tupla_lecturas)
# Out:
# 2520218453952

# %%
precios = [15000, 8700, 23000, None, 9800, -100, 45000]

# %%
precios_positivos_sin_none = [p for p in precios if p is not None and p >= 0]
precios_positivos_sin_none
# Out:
# [15000, 8700, 23000, 9800, 45000]

# %%
precios_con_descuento = [p-0.12*p for p in precios_positivos_sin_none]
precios_con_descuento
# Out:
# [13200.0, 7656.0, 20240.0, 8624.0, 39600.0]

# %%
15000-0.12*15000
# Out:
# 13200.0

# %%
[p*(1-0.12) for p in precios_positivos_sin_none]
# Out:
# [13200.0, 7656.0, 20240.0, 8624.0, 39600.0]

# %%
[p*0.88 for p in precios_positivos_sin_none]
# Out:
# [13200.0, 7656.0, 20240.0, 8624.0, 39600.0]

# %%
23000 in precios
# Out:
# True

# %%
precios
# Out:
# [15000, 8700, 23000, None, 9800, -100, 45000]
