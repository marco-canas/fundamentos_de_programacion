# %% [markdown]
# # Componente Práctico del Parcial – Fundamentos de Programación con Python (Ciencia de Datos)
#
# Instrucciones:
# 1. Responda cada ejercicio escribiendo el código Python correspondiente en el IDLE de Python.
# 2. Debe presentar sintaxis correcta e identación adecuada.
# 3. No se permite el uso de internet ni librerías externas.
# 4. Puede usar únicamente Python estándar.
# 5. Cuando sea necesario, muestre el resultado usando print().

# %% [markdown]
# 1. Cree una variable x=5 y calcule f(x)=x**2-3*x+2.

# %%
# Escriba aquí su código

# %% [markdown]
# 2. Cree dos variables a=7 y b=3. Calcule a**2 + b**2.

# %%
# Escriba aquí su código

# %% [markdown]
# 3. Cree una variable r=4 y calcule el área del círculo A = pi*r**2 usando pi=3.1416.

# %%
# Escriba aquí su código

# %% [markdown]
# 4. Cree variables x=3, y=4 y calcule la distancia al origen sqrt(x**2+y**2).

# %%
# Escriba aquí su código

# %% [markdown]
# 5. Cree una variable n=27 y determine si es divisible por 3 usando el operador %.

# %%
# Escriba aquí su código

# %% [markdown]
# 6. Cree una variable x=2 y evalúe f(x)=x**3 - 2*x + 1.

# %%
# Escriba aquí su código

# %% [markdown]
# 7. Cree variables a=5 y b=9 y verifique si a<b usando operadores relacionales.

# %%
# Escriba aquí su código

# %% [markdown]
# 8. Cree variables x=4, y=6 y determine si x<y and y<10.

# %%
# Escriba aquí su código

# %% [markdown]
# 9. Cree una variable x=3 y verifique si 1<x<5.

# %%
# Escriba aquí su código

# %% [markdown]
# 10. Cree variables a=8, b=2 y calcule la división entera a//b.

# %%
# Escriba aquí su código

# %% [markdown]
# 11. Cree una lista con los números 1,2,3,4,5.

# %%
# Escriba aquí su código

# %% [markdown]
# 12. Cree una lista con los cuadrados de 1,2,3,4,5.

# %%
# Escriba aquí su código

# %% [markdown]
# 13. Cree una lista con los valores de f(x)=x**2 para x=1..5.

# %%
# Escriba aquí su código

# %% [markdown]
# 14. Cree una lista llamada puntos con (0,0),(1,1),(2,4),(3,9).

# %%
# Escriba aquí su código

# %% [markdown]
# 15. Cree una lista A=[2,4,6,8] y agregue el número 10.

# %%
# Escriba aquí su código

# %% [markdown]
# 16. Cree una lista B=[1,3,5,7] y acceda al tercer elemento.

# %%
# Escriba aquí su código

# %% [markdown]
# 17. Cree una lista con los valores de la función f(x)=2*x+1 para x=0..4.

# %%
# Escriba aquí su código

# %% [markdown]
# 18. Cree una tupla que represente el vector (3,-1,2).

# %%
# Escriba aquí su código

# %% [markdown]
# 19. Cree una tupla con las coordenadas del punto (4,5).

# %%
# Escriba aquí su código

# %% [markdown]
# 20. Cree una tupla con tres números y calcule su suma.

# %%
# Escriba aquí su código

# %% [markdown]
# 21. Cree un conjunto A={1,2,3,4}.

# %%
# Escriba aquí su código

# %% [markdown]
# 22. Cree un conjunto B={3,4,5,6}.

# %%
# Escriba aquí su código

# %% [markdown]
# 23. Calcule la unión de A y B.

# %%
# Escriba aquí su código

# %% [markdown]
# 24. Calcule la intersección de A y B.

# %%
# Escriba aquí su código

# %% [markdown]
# 25. Calcule la diferencia A-B.

# %%
# Escriba aquí su código

# %% [markdown]
# 26. Cree una lista con números pares entre 2 y 10.

# %%
# Escriba aquí su código

# %% [markdown]
# 27. Cree una lista con los valores de x**3 para x=1..5.

# %%
# Escriba aquí su código

# %% [markdown]
# 28. Cree una variable x=10 y use operadores de asignación para sumar 5.

# %%
# Escriba aquí su código

# %% [markdown]
# 29. Cree una variable y=20 y use operadores de asignación para multiplicar por 2.

# %%
# Escriba aquí su código

# %% [markdown]
# 30. Cree variables x=3,y=4,z=5 y verifique si forman un triángulo rectángulo evaluando x**2+y**2==z**2.

# %%
# Escriba aquí su código
