# %%
import os

# Ruta base solicitada
base_path = r"C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu"

# Estructura de carpetas para el Jupyter Book y el curso
folders = [
    "_build",
    "_static",
    "_templates",
    "programa",
    "clases/unidad1",
    "clases/unidad2",
    "clases/unidad3",
    "clases/unidad4",
    "notebooks/unidad1",
    "notebooks/unidad2",
    "notebooks/unidad3",
    "notebooks/unidad4",
    "talleres/taller1",
    "talleres/taller2",
    "talleres/taller3",
    "talleres/taller4",
    "proyectos/guia",
    "proyectos/ejemplos",
    "datos/csv",
    "datos/sql",
    "datos/ejemplos",
    "recursos/bibliografia",
    "recursos/videos",
    "recursos/presentaciones",
    "docs"
]

# Crear carpetas
for folder in folders:
    folder_path = os.path.join(base_path, folder)
    os.makedirs(folder_path, exist_ok=True)
    print(f"✔ Carpeta creada o existente: {folder_path}")

# Crear archivos básicos para Jupyter Book
config_content = """
# Configuración base del Jupyter Book
title: "Fundamentos de Programación - Universidad de Antioquia"
author: "Instituto de Matemáticas - Facultad de Ciencias Exactas y Naturales"
logo: ""
only_build_toc_files: true

execute:
  execute_notebooks: auto
"""

toc_content = """
format: jb-book
root: intro

chapters:
  - file: programa/Programa_Fundamentos_Programacion
  - part: "Clases"
    chapters:
      - file: clases/unidad1/index
      - file: clases/unidad2/index
      - file: clases/unidad3/index
      - file: clases/unidad4/index
  - part: "Notebooks"
    chapters:
      - file: notebooks/unidad1/index
      - file: notebooks/unidad2/index
      - file: notebooks/unidad3/index
      - file: notebooks/unidad4/index
  - part: "Talleres"
    chapters:
      - file: talleres/taller1/index
      - file: talleres/taller2/index
      - file: talleres/taller3/index
      - file: talleres/taller4/index
  - part: "Proyectos"
    chapters:
      - file: proyectos/guia/index
      - file: proyectos/ejemplos/index
"""

# Crear archivos de configuración
with open(os.path.join(base_path, "_config.yml"), "w", encoding="utf-8") as f:
    f.write(config_content.strip())

with open(os.path.join(base_path, "_toc.yml"), "w", encoding="utf-8") as f:
    f.write(toc_content.strip())

print("\n🎉 Estructura del curso creada exitosamente.")
print("Archivos _config.yml y _toc.yml generados.")
# Out:
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\_build
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\_static
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\_templates
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\programa
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\clases/unidad1
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\clases/unidad2
# ✔ Carpeta creada o existente: C:\Users\marco\Documentos\docencia\fundamentos_de_programacion\1_planeacion_clases_evalu\clases/unidad3
# ...
