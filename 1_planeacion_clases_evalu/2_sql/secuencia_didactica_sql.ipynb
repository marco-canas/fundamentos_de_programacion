# %% [markdown]
# Aquí tienes una **secuencia didáctica completa, clara y progresiva** especialmente diseñada para tu formación como **matemático en Colombia**, integrando pensamiento lógico, análisis estructurado y el enfoque de datos que hoy exige la academia y el sector productivo (incluyendo educación, investigación y sector agropecuario).
#
# La secuencia está pensada para estudiantes con bases en lógica, estructuras y razonamiento matemático, pero sin experiencia previa en SQL.
#
# ---

# %% [markdown]
# # **SECUENCIA DIDÁCTICA: Introducción a SQL para la Formación de un Matemático**
#
# ---

# %% [markdown]
# ## 🎯 **Propósitos formativos (alineados con un perfil matemático en Colombia)**
#
# 1. Comprender el papel de SQL en la ciencia de datos, la modelación, la investigación y la administración académica y agropecuaria (IDEAM, salud pública, economía rural, registros educativos, etc.).
# 2. Desarrollar pensamiento estructural mediante el diseño y la consulta de bases de datos.
# 3. Promover el trabajo reproducible y la ciencia abierta usando SQL + Python (pandas + sqlite3 / SQLAlchemy).
# 4. Desarrollar competencias para:
#
#    * **modelar datos como relaciones**
#    * **formular consultas lógicas y cuantitativas**
#    * **explorar grandes volúmenes de datos reales del territorio**
# 5. Aplicar SQL en proyectos contextualizados: educación, salud pública, clima, agro, o gestión académica.
#
# ---

# %% [markdown]
# # **Estructura general de la secuencia (6 módulos)**

# %% [markdown]
# Cada módulo incluye: objetivo, contenido, actividad práctica, evaluación formativa y un mini-proyecto.
#
# ---

# %% [markdown]
# # **MÓDULO 1 — ¿Qué es SQL y por qué un matemático debe conocerlo?**
#
# ## Objetivo
#
# Comprender el papel de SQL en la gestión y análisis de datos, y su relación con el pensamiento lógico-matemático.

# %% [markdown]
# ## Contenidos
#
# * ¿Qué es una base de datos?
# * Datos como estructuras discretas.
# * Modelo relacional: conceptos de *relación*, *tupla* y *atributo*.
# * SQL como lenguaje declarativo (comparación con lenguajes procedimentales).
# * Ejemplos reales en Colombia:

# %% [markdown]
#   * datos IDEAM
#   * datos de salud pública SIVIGILA
#   * datos académicos universitarios
#   * datos agropecuarios (Fedearroz, UPRA)

# %% [markdown]
# # Actividad práctica
#
# * Explorar una base SQLite pequeña ya creada.
# * Ejecutar las primeras sentencias en un entorno simple:
#
# ```sql
# SELECT * FROM estudiantes;
# SELECT nombre, edad FROM estudiantes;
# ```

# %% [markdown]
# ## ✔ Evaluación formativa
#
# Explicar **por qué SQL es declarativo** y dar 3 ejemplos de cómo un matemático podría usarlo en investigación.
#
# ---
#
# # **MÓDULO 2 — Modelación de datos: tablas, tipos y relaciones**
#
# ## 🎯 Objetivo
#
# Diseñar estructuras de datos relacionando tablas y llaves.
#
# ## 📚 Contenidos
#
# * Tipos de datos: INTEGER, REAL, TEXT, DATE.
# * Llaves primarias y foráneas.
# * Relaciones: 1–1, 1–N, N–M.
# * Integridad referencial.
# * Normalización (1FN, 2FN, 3FN) sin excesivo formalismo.
#
# ## 📝 Actividad práctica
#
# Diseñar en papel una base de datos para un contexto colombiano, por ejemplo:
#
# **Base de datos "Clima y cultivo en Caucasia":**
#
# * estación
# * mediciones
# * parcelas
# * cultivos
#
# ## ✔ Evaluación formativa
#
# Identificar las llaves primarias y foráneas de un diseño dado.
#
# ---
#
# # **MÓDULO 3 — Consultas fundamentales (SELECT, WHERE, ORDER, LIMIT)**
#
# ## 🎯 Objetivo
#
# Formular consultas básicas para explorar datos.
#
# ## 📚 Contenidos
#
# * SELECT
# * WHERE (condiciones lógicas)
# * ORDER BY (creciente y decreciente)
# * LIMIT
# * Operadores lógicos (AND, OR, NOT)
# * Comparaciones numéricas
#
# ## 📝 Actividad práctica
#
# Usar un dataset simple:
#
# ```sql
# SELECT fecha, temperatura
# FROM clima
# WHERE temperatura > 28
# ORDER BY fecha DESC
# LIMIT 10;
# ```
#
# ## ✔ Evaluación formativa
#
# Escribir tres consultas para:
#
# * filtrar los días más lluviosos
# * encontrar valores fuera de rango
# * ordenar de mayor a menor humedad
#
# ---
#
# # **MÓDULO 4 — Agregaciones y funciones (GROUP BY, HAVING, SUM, AVG, COUNT)**
#
# ## 🎯 Objetivo
#
# Analizar datos agrupados para obtener perspectivas estadísticas simples.
#
# ## 📚 Contenidos
#
# * Funciones: COUNT(), SUM(), AVG(), MIN(), MAX()
# * GROUP BY
# * HAVING
# * Uso de agregaciones para análisis exploratorio
#
# ## 📝 Actividad práctica
#
# Ejemplo usando cultivos o datos académicos:
#
# ```sql
# SELECT cultivo, AVG(rendimiento) AS promedio
# FROM parcelas
# GROUP BY cultivo
# HAVING promedio > 5;
# ```
#
# ## ✔ Evaluación formativa
#
# Realizar un análisis exploratorio de un dataset:
#
# * promedio de notas
# * media de temperaturas
# * total de animales por finca
# * número de estudiantes por programa
#
# ---
#
# # **MÓDULO 5 — Joins: el corazón del pensamiento relacional**
#
# ## 🎯 Objetivo
#
# Comprender y usar correctamente JOINS para integrar información de múltiples tablas.
#
# ## 📚 Contenidos
#
# * INNER JOIN
# * LEFT JOIN
# * RIGHT JOIN
# * FULL JOIN (dependiendo del gestor)
# * Claves para entender la lógica del producto cartesiano y la selección
#
# ## 📝 Actividad práctica
#
# Ejemplo:
#
# ```sql
# SELECT e.nombre, c.temperatura
# FROM estudiantes e
# JOIN clima c ON e.id = c.obs_por;
# ```
#
# ## ✔ Evaluación formativa
#
# Explicar con diagramas (o con conjuntos) la diferencia entre INNER JOIN y LEFT JOIN.
#
# ---
#
# # **MÓDULO 6 — SQL + Python + Ciencia reproducible**
#
# ## 🎯 Objetivo
#
# Integrar SQL con Python para análisis y modelación matemático-computacional.
#
# ## 📚 Contenidos
#
# * Uso de SQLite con Python (`sqlite3`, `SQLAlchemy`, `pandas.read_sql`)
# * Construcción de pipelines reproducibles
# * Exportación y visualización con pandas/matplotlib
# * Buenas prácticas:
#
#   * versionamiento
#   * respaldo de bases
#   * documentación
#   * compartir scripts (GitHub)
#
# ## 📝 Actividad práctica
#
# Ejemplo en Python:
#
# ```python
# import sqlite3
# import pandas as pd
#
# conn = sqlite3.connect("clima.db")
#
# df = pd.read_sql("SELECT fecha, temperatura FROM clima WHERE temperatura > 30", conn)
# df.plot()
# ```
#
# ## ✔ Evaluación formativa
#
# Construir un pequeño **proyecto de datos** integrando SQL + Python con un repositorio GitHub.
#
# ---

# %% [markdown]
# # 📊 **Proyecto final de la secuencia: "Geodatos y Matemática Aplicada en Colombia"**
#
# Los estudiantes deben:
#
# 1. Seleccionar un conjunto de datos del contexto colombiano:
#
#    * Clima (IDEAM)
#    * Agro (Fedearroz, AGROSAVIA)
#    * Salud pública (INS)
#    * Educación (SPADIES, SNIES)
# 2. Crear una base de datos relacional bien estructurada.
# 3. Formular al menos 20 consultas (básicas + JOIN + agregación).
# 4. Exportar resultados con Python a gráficas o tablas.
# 5. Entregar un informe reproducible en GitHub.
#
# ---

# %% [markdown]
# # 📘 Material complementario (si quieres, te lo genero)
#
# Puedo prepararte ahora mismo:
#
# * Un **notebook de inicio** sobre SQL + Python.
# * Una **base de datos de ejemplo** (SQLite) contextualizada al Bajo Cauca Antioqueño.
# * Una **rueda de problemas** con 20 ejercicios para fortalecer el pensamiento relacional.
# * Una **guía de clase** en PDF para tus cursos universitarios.
#
# ¿Quieres que prepare alguno de estos materiales?
